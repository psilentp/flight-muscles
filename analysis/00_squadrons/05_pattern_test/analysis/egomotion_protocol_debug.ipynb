# %%
def plot_summary(flylist,axlist,plot_signal = 'rwing',trial = 'T2_trial1_ave_data.cpkl', plot_flies = False):
    ax0 = axlist[0]
    ax1 = axlist[1]
    ax2 = axlist[2]
    ax3 = axlist[3]
    ###stim trace
    f = open('/media/FlyDataB/FlyDB/Fly0187/' + 'stim_data.cpkl')
    stim = cPickle.load(f)['stim']
    f.close()

    static_test_90 = list()
    static_test_270 = list()

    stripe_test_90 = list()
    stripe_test_270 = list()

    opti_test_90 = list()
    opti_test_270 = list()
    
    
    for i,rootdir in enumerate(flylist):
        sr = 100*1000
        dt = 1.0/sr
        f = open(rootdir+trial)
        datadict = cPickle.load(f)[plot_signal]
        times = np.arange(shape(datadict['static_test_90'])[0])*dt
        #axes(ax1)
        #plot(times,rad2deg(datadict['static_test_90']/5),'r',alpha = 0.2)
        static_test_90.append(rad2deg(datadict['static_test_90']/5))
        #plot(times,rad2deg(datadict['static_test_270']/5),'b',alpha = 0.2)
        static_test_270.append(rad2deg(datadict['static_test_270']/5))
        #axes(ax2)
        #plot(times,rad2deg(datadict['stripe_test_90']/5),'r',alpha = 0.2)
        stripe_test_90.append(rad2deg(datadict['stripe_test_90']/5))
        #plot(times,rad2deg(datadict['stripe_test_270']/5),'b',alpha = 0.2)
        stripe_test_270.append(rad2deg(datadict['stripe_test_270']/5))
        #axes(ax3)
        #plot(times,rad2deg(datadict['opti_test_90']/5),'r',alpha = 0.2)
        opti_test_90.append(rad2deg(datadict['opti_test_90']/5))
        #plot(times,rad2deg(datadict['opti_test_270']/5),'b',alpha = 0.2)
        opti_test_270.append(rad2deg(datadict['opti_test_270']/5))
        
    for ax,t90,t270 in [[ax1,static_test_90,static_test_270],
                       [ax2,stripe_test_90,stripe_test_270],
                       [ax3,opti_test_90,opti_test_270]]:
        axes(ax)
        m90 = mean(t90,axis = 0)
        m270 = mean(t270,axis = 0)
        sd90 = std(t90,axis = 0)
        sd270 = std(t270,axis = 0)
        fill_between(times,m90+sd90,m90-sd90,facecolor = 'r',alpha = 0.2)
        plot(times,m90,'r')
        fill_between(times,m270+sd270,m270-sd270,facecolor = 'b',alpha = 0.2)
        plot(times,m270,'b')
        #plot(times,zeros_like(times),'k')
    
    axes(ax0)
    plot(times,stim,'r')
    plot(times,stim*-1,'b')

# %%
figure(figsize = (9,12))
import cPickle
"""
light_on =  ['/media/FlyDataB/FlyDB/Fly0182/',
            '/media/FlyDataB/FlyDB/Fly0183/',
            '/media/FlyDataB/FlyDB/Fly0184/',
            '/media/FlyDataB/FlyDB/Fly0185/',
            '/media/FlyDataB/FlyDB/Fly0186/',
            '/media/FlyDataB/FlyDB/Fly0187/',
            '/media/FlyDataB/FlyDB/Fly0189/',
            '/media/FlyDataB/FlyDB/Fly0191/',
            '/media/FlyDataB/FlyDB/Fly0192/',
            '/media/FlyDataB/FlyDB/Fly0193/',
            '/media/FlyDataB/FlyDB/Fly0194/',
            '/media/FlyDataB/FlyDB/Fly0195/',
            '/media/FlyDataB/FlyDB/Fly0196/',
            '/media/FlyDataB/FlyDB/Fly0197/']
"""

light_on_off =  ['/media/FlyDataB/FlyDB/Fly0191/','/media/FlyDataB/FlyDB/Fly0192/',
            '/media/FlyDataB/FlyDB/Fly0193/','/media/FlyDataB/FlyDB/Fly0194/']

light_on_trial = 'T2_trial1_ave_data.cpkl'
flylist = light_on

flylist = light_on_off
light_on_trial = 'T2_trial2_ave_data.cpkl'

axlist1 = list()
axlist1.append(subplot(4,3,1))
axlist1.append(subplot(4,3,4,sharex = axlist1[0]))
axlist1.append(subplot(4,3,7,sharex = axlist1[0]))
axlist1.append(subplot(4,3,10,sharex = axlist1[0]))

axlist2 = list()
axlist2.append(subplot(4,3,2))
axlist2.append(subplot(4,3,5,sharex = axlist2[0]))
axlist2.append(subplot(4,3,8,sharex = axlist2[0]))
axlist2.append(subplot(4,3,11,sharex = axlist2[0]))

axlist3 = list()
axlist3.append(subplot(4,3,3))
axlist3.append(subplot(4,3,6,sharex = axlist3[0]))
axlist3.append(subplot(4,3,9,sharex = axlist3[0]))
axlist3.append(subplot(4,3,12,sharex = axlist3[0]))

plot_summary(flylist,axlist1,plot_signal = 'lmr',trial = light_on_trial)
plot_summary(flylist,axlist2,plot_signal = 'lwings',trial = light_on_trial)
plot_summary(flylist,axlist3,plot_signal = 'rwings',trial = light_on_trial)

axlist1[-1].set_ybound((-25,25))
axlist1[-2].set_ybound((-25,25))
axlist1[-3].set_ybound((-25,25))
axlist1[-4].set_ybound((-3,3))

axlist2[-1].set_ybound((20,55))
axlist2[-2].set_ybound((20,55))
axlist2[-3].set_ybound((20,55))
axlist2[-4].set_ybound((-3,3))

axlist3[-1].set_ybound((20,55))
axlist3[-2].set_ybound((20,55))
axlist3[-3].set_ybound((20,55))
axlist3[-4].set_ybound((-3,3))

axlist1[-1].set_xbound((0,3))
axlist2[-1].set_xbound((0,3))
axlist3[-1].set_xbound((0,3))

axlist1[0].set_title('left-right')
axlist2[0].set_title('left wing')
axlist3[0].set_title('right wing')
axlist1[1].set_ylabel('static pattern')
axlist1[2].set_ylabel('stripe on static pattern')
axlist1[3].set_ylabel('optimotor yaw')
axlist1[-1].set_xlabel('time s')
draw()
display(gcf())
close()

# %%
figure(figsize = (9,12))
import cPickle
light_on_off =  ['/media/FlyDataB/FlyDB/Fly0191/','/media/FlyDataB/FlyDB/Fly0192/',
            '/media/FlyDataB/FlyDB/Fly0193/','/media/FlyDataB/FlyDB/Fly0194/']

light_on_trial = 'T2_trial1_ave_data.cpkl'
light_off_trial = 'T2_trial2_ave_data.cpkl'
flylist = light_on_off

axlist1 = list()
axlist1.append(subplot(4,2,1))
axlist1.append(subplot(4,2,3,sharex = axlist1[0]))
axlist1.append(subplot(4,2,5,sharex = axlist1[0]))
axlist1.append(subplot(4,2,7,sharex = axlist1[0]))

axlist2 = list()
axlist2.append(subplot(4,2,2))
axlist2.append(subplot(4,2,4,sharex = axlist2[0]))
axlist2.append(subplot(4,2,6,sharex = axlist2[0]))
axlist2.append(subplot(4,2,8,sharex = axlist2[0]))

plot_summary(flylist,axlist1,plot_signal = 'lmr',trial = light_on_trial)
plot_summary(flylist,axlist2,plot_signal = 'lmr',trial = light_off_trial)

axlist1[-1].set_ybound((-25,25))
axlist1[-2].set_ybound((-25,25))
axlist1[-3].set_ybound((-25,25))
axlist1[-4].set_ybound((-3,3))

axlist2[-1].set_ybound((-25,25))
axlist2[-2].set_ybound((-25,25))
axlist2[-3].set_ybound((-25,25))
axlist2[-4].set_ybound((-3,3))

axlist1[-1].set_xbound((0,3))
axlist2[-1].set_xbound((0,3))

axlist1[0].set_title('left-right (light on)')
axlist2[0].set_title('left-right (light off)')
axlist1[1].set_ylabel('static pattern')
axlist1[2].set_ylabel('stripe on static pattern')
axlist1[3].set_ylabel('optimotor yaw')
axlist1[-1].set_xlabel('time s')
draw()
display(gcf())
close()

# %%
##plot left and right amplitudes during sripe fixation
import flylib as flb
import os
rootdir = '/media/FlyDataB/FlyDB/Fly0193/'
abf_file = filter(lambda x:'.abf' in x,os.listdir(rootdir))[0]
sigs = flb.get_axon_signals(rootdir + abf_file)
import gc;gc.collect()

# %%
# Out:
# 34487

# %%
figure(figsize = (15,3))
sta = -10000000
stp = -8000000
ste = 10
tms = sigs['times'][sta:stp:ste]
ax0 = subplot(2,1,1)
plot(tms,sigs['Xpos'][sta:stp:ste])
subplot(2,1,2,sharex = ax0)
plot(tms,rad2deg(sigs['Ph0'][sta:stp:ste]/5),'green',lw=2)
plot(tms,rad2deg(sigs['Ph1'][sta:stp:ste]/5),'orange',lw=2)
axis('tight')
display(gcf())
close()

# %%
import cPickle
f = open('/media/FlyDataB/FlyDB/Fly0195/T2_trial2_ave_data.cpkl')
datadict = cPickle.load(f)
f.close()

# %%
figure()
plot(datadict['rwings']['opti_test_90'])
plot(datadict['rwings']['opti_test_270'])
suptitle('rwing')
gca().set_ybound((0,10))
figure()
plot(datadict['lwings']['opti_test_90'])
plot(datadict['lwings']['opti_test_270'])
suptitle('lwing')
gca().set_ybound((0,10))

# %%
import flylib as flb
import neo
import os
import gc

rootdir = '/media/FlyDataB/FlyDB/Fly0199/'
abf_file = filter(lambda x:'.abf' in x,os.listdir(rootdir))[0]
sigs = flb.get_axon_signals(rootdir + abf_file)
gc.collect()
idxs = flb.idx_by_thresh(sigs['DAC2'],thresh = 0)
t_codes = np.array([sigs['DAC2'][x] for x in idxs])
t_vals = around(array([mean(tc) for tc in t_codes])*6)
t_args = argsort(t_vals)
static_test_90 = squeeze(argwhere(t_vals == 10))
static_test_270 = squeeze(argwhere(t_vals == 20))
stripe_test_90 = squeeze(argwhere(t_vals == 30))
stripe_test_270 = squeeze(argwhere(t_vals == 40))
opti_test_90 = squeeze(argwhere(t_vals == 50))
opti_test_270 = squeeze(argwhere(t_vals == 60))
lmrs = np.array([sigs['Ph2'][x[:280000]] for x in idxs])
lwings = np.array([sigs['Ph0'][x[:280000]] for x in idxs])
rwings = np.array([sigs['Ph1'][x[:280000]] for x in idxs])
Ypos = np.array([sigs['Ypos'][x[:280000]] for x in idxs])
Xpos = np.array([sigs['Xpos'][x[:280000]] for x in idxs])
ttype = static_test_90
####################
figure()
subplot(3,1,1)
ave = mean(Ypos[ttype],axis=0)
stdev = std(Ypos[ttype],axis=0)
plot(ave,c = 'k')
plot(ave+stdev,c = 'b')
plot(ave-stdev,c = 'b')
i = 2
for ttype in [static_test_90,static_test_270]:
    subplot(3,1,i)
    ave = mean(lwings[ttype],axis=0)
    stdev = std(lwings[ttype],axis=0)
    plot(ave,c = 'k')
    plot(ave+stdev,c = 'b')
    plot(ave-stdev,c = 'b')
    i+=1
    gca().set_ybound(-3,3)
suptitle('static')

##################
figure()
subplot(3,1,1)
ave = mean(Ypos[ttype],axis=0)
stdev = std(Ypos[ttype],axis=0)
plot(ave,c = 'k')
plot(ave+stdev,c = 'b')
plot(ave-stdev,c = 'b')
i = 2
for ttype in [opti_test_90,opti_test_270]:
    subplot(3,1,i)
    ave = mean(lwings[ttype],axis=0)
    stdev = std(lwings[ttype],axis=0)
    plot(ave,c = 'k')
    plot(ave+stdev,c = 'b')
    plot(ave-stdev,c = 'b')
    i+=1
    gca().set_ybound(-3,3)
suptitle('opti')

##################
figure()
subplot(3,1,1)
ave = mean(Ypos[ttype],axis=0)
stdev = std(Ypos[ttype],axis=0)
plot(ave,c = 'k')
plot(ave+stdev,c = 'b')
plot(ave-stdev,c = 'b')
i = 2
for ttype in [stripe_test_90,stripe_test_270]:
    subplot(3,1,i)
    ave = mean(lwings[ttype],axis=0)
    stdev = std(lwings[ttype],axis=0)
    plot(ave,c = 'k')
    plot(ave+stdev,c = 'b')
    plot(ave-stdev,c = 'b')
    i+=1
    gca().set_ybound(-3,3)
suptitle('stripe')


ave_dict_lmr = {'static_test_90':mean(lmrs[static_test_90],axis=0),
            'static_test_270':mean(lmrs[static_test_270],axis=0),
            'stripe_test_90':mean(lmrs[stripe_test_90],axis=0),
            'stripe_test_270':mean(lmrs[stripe_test_270],axis=0),
            'opti_test_90':mean(lmrs[opti_test_90],axis=0),
            'opti_test_270':mean(lmrs[opti_test_270],axis=0)}

ave_dict_lwings = {'static_test_90':mean(lwings[static_test_90],axis=0),
            'static_test_270':mean(lwings[static_test_270],axis=0),
            'stripe_test_90':mean(lwings[stripe_test_90],axis=0),
            'stripe_test_270':mean(lwings[stripe_test_270],axis=0),
            'opti_test_90':mean(lwings[opti_test_90],axis=0),
            'opti_test_270':mean(lwings[opti_test_270],axis=0)}

ave_dict_rwings = {'static_test_90':mean(rwings[static_test_90],axis=0),
            'static_test_270':mean(rwings[static_test_270],axis=0),
            'stripe_test_90':mean(rwings[stripe_test_90],axis=0),
            'stripe_test_270':mean(rwings[stripe_test_270],axis=0),
            'opti_test_90':mean(rwings[opti_test_90],axis=0),
            'opti_test_270':mean(rwings[opti_test_270],axis=0)}



import cPickle
f = open(rootdir + 'T2_trial1_ave_data.cpkl','wb')
cPickle.dump({'lmr':ave_dict_lmr,'lwings':ave_dict_lwings,'rwings':ave_dict_rwings},f)
f.close()

# %%
# Out:
# (691.96159999999998, 711.9615, 13.099974632263184, 59.988510131835938)

# %%
stim_data = {'stim':mean(Ypos[ttype],axis=0)}
f = open(rootdir + 'stim_data.cpkl','wb')
cPickle.dump(stim_data,f)
f.close()

# %%
rootdir
# Out:
# '/media/FlyDataB/FlyDB/Fly0195/'

# %%
1.05*5
# Out:
# 5.25

# %%
abf_file
# Out:
# 'T2_trial2_14808005.abf'

# %%
fls = os.listdir(rootdir)

# %%
# Out:
# 'T2_trial1_14805002.abf'

# %%
400/156.0
# Out:
# 2.5641025641025643

# %%
# Out:
# array([ 20.,  20.,  20.,  20.,  20.,  20.,  20.,  20.,  20.,  20.,  20.,
#         20.], dtype=float32)

# %%
1.12/(274*2.5/1000)
# Out:
# 1.635036496350365

# %%
####################
figure()
subplot(3,1,1)
ave = mean(Ypos[ttype],axis=0)
stdev = std(Ypos[ttype],axis=0)
plot(ave,c = 'k')
plot(ave+stdev,c = 'b')
plot(ave-stdev,c = 'b')
i = 2
for ttype in [static_test_90,static_test_270]:
    subplot(3,1,i)
    ave = mean(rwings[ttype],axis=0)
    stdev = std(rwings[ttype],axis=0)
    plot(ave,c = 'k')
    plot(ave+stdev,c = 'b')
    plot(ave-stdev,c = 'b')
    i+=1
    gca().set_ybound(-3,3)
suptitle('static')

##################
figure()
subplot(3,1,1)
ave = mean(Ypos[ttype],axis=0)
stdev = std(Ypos[ttype],axis=0)
plot(ave,c = 'k')
plot(ave+stdev,c = 'b')
plot(ave-stdev,c = 'b')
i = 2
for ttype in [opti_test_90,opti_test_270]:
    subplot(3,1,i)
    ave = mean(rwings[ttype],axis=0)
    stdev = std(rwings[ttype],axis=0)
    plot(ave,c = 'k')
    plot(ave+stdev,c = 'b')
    plot(ave-stdev,c = 'b')
    i+=1
    gca().set_ybound(-3,3)
suptitle('opti')

##################
figure()
subplot(3,1,1)
ave = mean(Ypos[ttype],axis=0)
stdev = std(Ypos[ttype],axis=0)
plot(ave,c = 'k')
plot(ave+stdev,c = 'b')
plot(ave-stdev,c = 'b')
i = 2
for ttype in [stripe_test_90,stripe_test_270]:
    subplot(3,1,i)
    ave = mean(rwings[ttype],axis=0)
    stdev = std(rwings[ttype],axis=0)
    plot(ave,c = 'k')
    plot(ave+stdev,c = 'b')
    plot(ave-stdev,c = 'b')
    i+=1
    gca().set_ybound(-3,3)
suptitle('stripe')
