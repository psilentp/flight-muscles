# %%
import group_data as gd
import flylib
import numpy as np

# %%
# %pylab inline
# %config InlineBackend.figure_format = 'svg'
import pylab as plb
plb.rcParams['pdf.fonttype'] = 42
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import h5py
trial_db = h5py.File('trial_db.hdf5','r')
xi = np.linspace(0,23,1150)
tlag = xi-xi[1150/2.0]
tlag = tlag[:1149]
muscle_list =  ['b1','b2','b3',
                'i1','i2',
                'iii1','iii3','iii24',
                'hg1','hg2','hg3','hg4',
                'tpd','tpv','ttm','pr','wb_frequency','Ph1']
swarm_names = np.array(trial_db['swarm_names'])
fly_numbers = np.array(trial_db['fly_numbers'])
wb_frequency = np.array(trial_db['wb_frequency'])
trial_names = np.array(trial_db['trial_names'])
wb_selection = np.sum(wb_frequency >50,axis = 1)>1000
swarm_set = [sw for sw in set(swarm_names) if not('pr' in sw)]
fly_set = set(fly_numbers)
# Out:
# /home/psilentp/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:15: RuntimeWarning: invalid value encountered in greater

# %%
swarm = 'GMR22H05'
mname = 'b1'
stop_dict = dict()
trial_selection = (trial_names == 'flight_starts')

swarm_selection = (swarm == swarm_names) & trial_selection
for flynum in fly_set:
    selection  = (flynum == fly_numbers) & swarm_selection
    if sum(selection) > 2:
        extract = np.array(trial_db['wb_frequency'])[selection,:]
        include = np.sum(extract[:,0:200].T>10,axis = 0) < 100
        #print include
        if sum(include)>0:
            trace = nanmedian(np.array(trial_db[mname])[selection,:][include],axis = 0)
            plot(trace)
# Out:
# /home/psilentp/anaconda/lib/python2.7/site-packages/numpy/lib/nanfunctions.py:662: RuntimeWarning: All-NaN slice encountered
#   warnings.warn("All-NaN slice encountered", RuntimeWarning)

# %%
swarm = 'GMR22H05'
mname = 'b1'
trial_selection = (trial_names == 'flight_stops')
swarm_selection = (swarm == swarm_names) & trial_selection
for flynum in fly_set:
    selection  = (flynum == fly_numbers) & swarm_selection
    if sum(selection) > 2:
        extract = np.array(trial_db['wb_frequency'])[selection,:]
        include = np.sum(extract[:,225:500].T>10,axis = 0) < 100
        trace = nanmedian(np.array(trial_db[mname])[selection,:][include],axis = 0)
        plot(trace)
# Out:
# /home/psilentp/anaconda/lib/python2.7/site-packages/numpy/lib/nanfunctions.py:662: RuntimeWarning: All-NaN slice encountered
#   warnings.warn("All-NaN slice encountered", RuntimeWarning)
# /home/psilentp/anaconda/lib/python2.7/site-packages/numpy/lib/nanfunctions.py:598: RuntimeWarning: Mean of empty slice
#   warnings.warn("Mean of empty slice", RuntimeWarning)

# %%
#calculate the median xcov functions and
#load into a dictionary keyed by group and then muscle
start_dict = dict()
trial_selection = (trial_names == 'flight_starts')
#wb_selection = np.sum(wb_frequency >50)>1000
#wb_selection &= trial_selection
for swarm in swarm_set:
    print swarm
    swarm_selection = (swarm == swarm_names) & trial_selection
    start_dict[swarm] = dict()
    for mname in muscle_list:
        start_dict[swarm][mname] = list()
        for flynum in fly_set:
            selection  = (flynum == fly_numbers) & swarm_selection
            if sum(selection) > 2:
                extract = np.array(trial_db['wb_frequency'])[selection,:]
                include = np.sum(extract[:,0:200].T>10,axis = 0) < 100
                if sum(include)>2:
                    trace = nanmedian(np.array(trial_db[mname])[selection,:][include],axis = 0)
                    start_dict[swarm][mname].append(trace)
# Out:
# GMR22H05_GFP
# GMR31E10
# GMR75B06_GFP
# GMR22H05
# GMR29E05_GFP
# GMR39E01
# GMR31E10_GFP
# GMR10A12
# GMR74F03_GFP
# GMR39E01_GFP
# GMR75B06
# GMR74F03
# GMR29E05
# GMR10A12_GFP

# %%
#calculate the median xcov functions and
#load into a dictionary keyed by group and then muscle
stop_dict = dict()
trial_selection = (trial_names == 'flight_stops')
#wb_selection = np.sum(wb_frequency >50)>1000
#wb_selection &= trial_selection
for swarm in swarm_set:
    print swarm
    swarm_selection = (swarm == swarm_names) & trial_selection
    stop_dict[swarm] = dict()
    for mname in muscle_list:
        stop_dict[swarm][mname] = list()
        for flynum in fly_set:
            selection  = (flynum == fly_numbers) & swarm_selection
            if sum(selection) > 2:
                extract = np.array(trial_db['wb_frequency'])[selection,:]
                include = np.sum(extract[:,225:500].T>10,axis = 0) < 100
                if sum(include)>0:
                    trace = nanmedian(np.array(trial_db[mname])[selection,:][include],axis = 0)
                    stop_dict[swarm][mname].append(trace)
# Out:
# GMR22H05_GFP
# GMR31E10
# GMR75B06_GFP
# GMR22H05
# GMR29E05_GFP
# GMR39E01
# GMR31E10_GFP
# GMR10A12
# GMR74F03_GFP
# GMR39E01_GFP
# GMR75B06
# GMR74F03
# GMR29E05
# GMR10A12_GFP

# %%
import h5py
import os
#os.listdir('./')
os.remove('start_db.hdf5')
start_db = h5py.File('start_db.hdf5','a')
for key in start_dict:
    start_db.create_group(key)
    for key2 in start_dict[key].keys():
        start_db[key].create_dataset(key2,data = np.array(start_dict[key][key2]),  compression="gzip",compression_opts=5)
start_db.flush()

# %%
import h5py
import os
#os.listdir('./')
os.remove('stop_db.hdf5')
stop_db = h5py.File('stop_db.hdf5','a')
for key in stop_dict:
    stop_db.create_group(key)
    for key2 in stop_dict[key].keys():
        stop_db[key].create_dataset(key2,data = np.array(stop_dict[key][key2]),  compression="gzip",compression_opts=5)
stop_db.flush()

# %%
stop_dict
# Out:
# {'GMR10A12': {'b1': [array([ 0.15984727,  0.16072382,  0.16119213, ...,  0.14917067,
#            0.14792282,         nan]),
#    array([ 0.25435861,  0.25460759,  0.2511258 , ...,  0.22539094,
#            0.22716761,         nan])],
#   'b2': [array([ 0.03547706,  0.03245448,  0.0315624 , ...,  0.01430899,
#            0.01506871,         nan]),
#    array([ 0.00464735,  0.00588367,  0.0052035 , ...,  0.00666676,
#            0.00793728,         nan])],
#   'b3': [array([ 0.26169089,  0.26411106,  0.26566221, ...,  0.27177509,
#            0.27739326,         nan]),
#    array([ 0.27116211,  0.27086002,  0.26364768, ...,  0.28460112,
#            0.28142053,         nan])],
#   'hg1': [array([ 0.17169634,  0.16384966,  0.14266467, ...,  0.14918239,
#            0.16545781,         nan]),
#    array([ 0.03798511,  0.05082741,  0.04309796, ...,  0.13101539,
#            0.13132084,         nan])],
#   'hg2': [array([ 0.1012351 ,  0.04647986,  0.07292799, ...,  0.44195926,
#            0.45065172,         nan]),
#    array([ 1.6171475 ,  1.64427797,  1.62275484, ...,  2.10566863,
#            2.11586422,         nan])],
#   'hg3': [array([ 0.16429847,  0.16462092,  0.16558001, ...,  0.11585137,
#            0.11498323,         nan]),
#    array([ 0.13749953,  0.13018842,  0.13831649, ...,  0.02519767,
#            0.02579207,         nan])],
#   'hg4': [array([ 0.87554266,  0.8784951 ,  0.89661052, ...,  1.28717921,
#            1.27288794,         nan]),
#    array([ 0.43978414,  0.44288832,  0.42042515, ...,  0.80465655,
#            0.88362193,         nan])],
#   'i1': [array([ 0.08613277,  0.08931508,  0.08792092, ...,  0.13430465,
#            0.13236969,         nan]),
#    array([ 0.09001038,  0.09016165,  0.09050764, ...,  0.1012265 ,
#            0.11394573,         nan])],
#   'i2': [array([ 0.22953303,  0.21494733,  0.21993715, ...,  0.07801619,
#            0.05758204,         nan]),
#    array([ 0.15508756,  0.15372604,  0.16023105, ...,  0.2938663 ,
#            0.2965593 ,         nan])],
#   'iii1': [array([ 0.07998663,  0.07912639,  0.07916619, ...,  0.08821007,
#            0.087681  ,         nan]),
#    array([ 0.08048454,  0.07756562,  0.07681981, ...,  0.09751994,
#            0.09624021,         nan])],
#   'iii24': [array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan])],
#   'iii3': [array([ 0.4381457 ,  0.41899616,  0.38967597, ...,  0.6233209 ,
#            0.61830827,         nan]),
#    array([ 0.81054705,  0.80044957,  0.79949737, ...,  0.92052144,
#            0.92473273,         nan])],
#   'pr': [array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan])],
#   'tpd': [array([ 0.46471492,  0.46245609,  0.44378649, ...,  0.45314905,
#            0.43621821,         nan]),
#    array([ 0.29495276,  0.2848558 ,  0.27819015, ...,  0.26176175,
#            0.26041803,         nan])],
#   'tpv': [array([ 0.        ,  0.        ,  0.        , ...,  0.        ,
#            0.00236613,         nan]),
#    array([ 0.02952005,  0.03245857,  0.03389221, ...,  0.03902126,
#            0.04395725,         nan])],
#   'ttm': [array([ 0.01959977,  0.01905236,  0.01878437, ...,  0.01176968,
#            0.01168794,         nan]),
#    array([ 0.00782041,  0.00781149,  0.00778359, ...,  0.00625508,
#            0.00636573,         nan])],
#   'wb_frequency': [array([ 195.02959338,  195.07879339,  193.53802063, ...,  217.23294211,
#            217.23006861,           nan]),
#    array([ 196.50074377,  196.7058698 ,  193.19370719, ...,  208.40507803,
#            209.02049525,           nan])]},
#  'GMR10A12_GFP': {'b1': [],
#   'b2': [],
#   'b3': [],
#   'hg1': [],
#   'hg2': [],
#   'hg3': [],
#   'hg4': [],
#   'i1': [],
#   'i2': [],
#   'iii1': [],
#   'iii24': [],
#   'iii3': [],
#   'pr': [],
#   'tpd': [],
#   'tpv': [],
#   'ttm': [],
#   'wb_frequency': []},
#  'GMR22H05': {'b1': [array([ 0.37692276,  0.37925854,  0.38186036, ...,  0.37668011,
#            0.37659199,         nan]),
#    array([ 0.68531038,  0.68654788,  0.6862484 , ...,  0.0874284 ,
#            0.40437878,         nan]),
#    array([ 0.91637949,  0.91611497,  0.91322666, ...,  0.71815903,
#            0.79987431,         nan]),
#    array([ 0.93142998,  0.93187203,  0.92869102, ...,  0.72946641,
#            0.732509  ,         nan]),
#    array([ 1.00612161,  0.97352035,  1.01466646, ...,  0.        ,
#            0.9999431 ,         nan]),
#    array([ 0.90975605,  0.90797183,  0.90686179, ...,  0.87058934,
#            0.86719313,         nan]),
#    array([ 1.11922392,  1.1249572 ,  1.14032208, ...,  0.92842506,
#            0.90899247,         nan]),
#    array([ 1.20416053,  1.2053467 ,  1.20498145, ...,  1.23437011,
#            1.23126067,         nan]),
#    array([ 0.91186207,  0.9141686 ,  0.91573775, ...,  0.92258766,
#            0.91461725,         nan]),
#    array([ 1.08213654,  1.09685155,  1.09535519, ...,  0.60591721,
#            0.60518163,         nan]),
#    array([ 1.12387462,  1.11852812,  1.11554788, ...,  1.20244369,
#            1.21782776,         nan]),
#    array([ 1.03285563,  1.03126767,  1.03550037, ...,  0.50559992,
#                   nan,         nan]),
#    array([ 0.97151554,  0.9772021 ,  0.9731077 , ...,  0.05352831,
#            0.04609445,         nan]),
#    array([ 0.83809831,  0.85216604,  0.86281989, ...,  0.97139323,
#            0.97243508,         nan]),
#    array([ 0.56716654,  0.54520279,  0.54610247, ...,  0.06016893,
#                   nan,         nan])],
#   'b2': [array([ 0.0429576 ,  0.04064069,  0.03628854, ...,  0.0406583 ,
#            0.03977014,         nan]),
#    array([ 0.21928815,  0.21834675,  0.21670877, ...,  0.07373814,
#            0.15796762,         nan]),
#    array([ 0.05816799,  0.0600954 ,  0.05288403, ...,  0.00856649,
#            0.00151587,         nan]),
#    array([ 0.16239712,  0.15699287,  0.15695431, ...,  0.1510174 ,
#            0.1524556 ,         nan]),
#    array([ 0.        ,  0.00272099,  0.00941158, ...,  0.        ,
#            0.        ,         nan]),
#    array([ 0.06913578,  0.0639445 ,  0.06501379, ...,  0.04910611,
#            0.04976319,         nan]),
#    array([ 0.10633744,  0.1043268 ,  0.10490771, ...,  0.12681002,
#            0.12411328,         nan]),
#    array([ 0.08822109,  0.09116387,  0.08286917, ...,  0.05541925,
#            0.05258911,         nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([ 0.17270154,  0.15598381,  0.14884533, ...,  0.16886593,
#            0.16195072,         nan]),
#    array([ 0.27335342,  0.27593124,  0.27885987, ...,  0.25655994,
#            0.26308378,         nan]),
#    array([ 0.05857688,  0.06125685,  0.06237607, ...,  0.2809545 ,
#                   nan,         nan]),
#    array([ 0.19645682,  0.202645  ,  0.20784248, ...,  0.05001443,
#            0.03804656,         nan]),
#    array([ 0.12332413,  0.125188  ,  0.12740285, ...,  0.12791384,
#            0.12459273,         nan]),
#    array([ 0.01723876,  0.00153925,  0.        , ...,  0.05653495,
#                   nan,         nan])],
#   'b3': [array([ 0.56395241,  0.5425038 ,  0.53942557, ...,  0.53437087,
#            0.54091464,         nan]),
#    array([ 0.67033239,  0.67334598,  0.67864544, ...,  0.        ,
#            1.05518532,         nan]),
#    array([ 0.97077856,  0.96650465,  0.96480647, ...,  0.90164687,
#            0.89626881,         nan]),
#    array([ 0.94957661,  0.985691  ,  0.99513382, ...,  1.05448228,
#            1.04843831,         nan]),
#    array([ 1.23238633,  1.2443425 ,  1.29379946, ...,  0.        ,
#            1.18937432,         nan]),
#    array([ 1.3840221 ,  1.39859021,  1.39667613, ...,  1.38872129,
#            1.39138386,         nan]),
#    array([ 1.99165882,  1.97616243,  1.97394677, ...,  1.88103167,
#            1.8523322 ,         nan]),
#    array([ 1.72273532,  1.72515556,  1.72698935, ...,  1.80022096,
#            1.79309623,         nan]),
#    array([ 1.38896743,  1.39781552,  1.38562988, ...,  1.53711076,
#            1.52943049,         nan]),
#    array([ 1.31879596,  1.26008825,  1.21244987, ...,  1.71795815,
#            1.69000906,         nan]),
#    array([ 2.12632186,  2.11505634,  2.12498954, ...,  2.06196249,
#            2.06219318,         nan]),
#    array([ 1.2743506 ,  1.28108968,  1.27758569, ...,  1.12610612,
#                   nan,         nan]),
#    array([ 1.51836252,  1.52354975,  1.53347721, ...,  0.06982329,
#            0.07430735,         nan]),
#    array([ 1.34758657,  1.33801026,  1.37395515, ...,  1.51998647,
#            1.50804643,         nan]),
#    array([ 0.52107114,  0.43549797,  0.43485122, ...,  0.00555818,
#                   nan,         nan])],
#   'hg1': [array([ 0.91556569,  0.9894319 ,  1.01192872, ...,  0.25148184,
#            0.46478192,         nan]),
#    array([ 0.53391381,  0.60978605,  0.66997223, ...,  0.00925618,
#            1.57337079,         nan]),
#    array([ 1.2879823 ,  1.25185121,  1.20796113, ...,  0.87453251,
#            0.80861786,         nan]),
#    array([ 0.51245852,  0.54764813,  0.59005268, ...,  0.58804792,
#            0.56800016,         nan]),
#    array([ 0.28842402,  0.29160712,  0.30162038, ...,  0.        ,
#            0.05772202,         nan]),
#    array([ 0.        ,  0.        ,  0.        , ...,  0.00900754,
#            0.0006176 ,         nan]),
#    array([ 1.4708224 ,  1.51435666,  1.50832804, ...,  1.69472009,
#            1.64250613,         nan]),
#    array([ 0.32509816,  0.31989753,  0.2782369 , ...,  1.50592614,
#            1.46234739,         nan]),
#    array([ 0.13025248,  0.12866251,  0.10887844, ...,  0.12736925,
#            0.13372333,         nan]),
#    array([ 0.90720094,  0.87825076,  0.83971514, ...,  4.12526968,
#            3.91893825,         nan]),
#    array([ 0.24115373,  0.22952857,  0.19038804, ...,  0.89102526,
#            1.54592779,         nan]),
#    array([ 1.41983541,  1.44247029,  1.49841861, ...,  1.65234971,
#                   nan,         nan]),
#    array([ 0.1088144 ,  0.08709072,  0.05029653, ...,  0.10569267,
#            0.04811007,         nan]),
#    array([ 0.43161418,  0.47622424,  0.44375906, ...,  0.32852029,
#            0.29300124,         nan]),
#    array([ 0.        ,  0.        ,  0.        , ...,  0.00069267,
#                   nan,         nan])],
#   'hg2': [array([ 2.40443409,  2.31697859,  2.25497519, ...,  0.97172077,
#            1.48168869,         nan]),
#    array([ 3.95145077,  3.94880192,  4.05422481, ...,  0.07264305,
#            6.38763335,         nan]),
#    array([ 2.40556676,  2.70914849,  2.70429468, ...,  1.7992777 ,
#            1.67417905,         nan]),
#    array([ 5.00627814,  5.34819185,  4.99604726, ...,  6.07908865,
#            5.80775512,         nan]),
#    array([ 1.91347975,  2.1739249 ,  2.21198327, ...,  0.        ,
#            1.70329645,         nan]),
#    array([ 0.        ,  0.        ,  0.        , ...,  0.0134185 ,
#            0.00261278,         nan]),
#    array([ 4.10580283,  4.10960053,  4.09222537, ...,  4.01560469,
#            3.87036246,         nan]),
#    array([ 1.81447363,  1.84827247,  1.72748094, ...,  5.66158383,
#            5.60644028,         nan]),
#    array([ 0.49150175,  0.44138271,  0.50060099, ...,  0.48684936,
#            0.53160136,         nan]),
#    array([ 5.30207112,  5.22001922,  4.92151026, ...,  9.27531679,
#            9.07181316,         nan]),
#    array([ 2.36499207,  2.40208256,  2.44402049, ...,  4.2522762 ,
#            6.22288544,         nan]),
#    array([ 2.63878859,  2.578965  ,  2.60070334, ...,  5.59291328,
#                   nan,         nan]),
#    array([ 0.68355463,  0.68866234,  0.63411534, ...,  0.        ,
#            0.        ,         nan]),
#    array([ 2.73324401,  2.68936165,  2.64443226, ...,  4.6706435 ,
#            4.49447133,         nan]),
#    array([  0.,   0.,   0., ...,   0.,  nan,  nan])],
#   'hg3': [array([ 0.74137828,  0.74553415,  0.77521009, ...,  0.22711388,
#            0.39437   ,         nan]),
#    array([ 0.36534015,  0.34375322,  0.40223746, ...,  0.01670756,
#            0.2320736 ,         nan]),
#    array([ 0.15092805,  0.16050047,  0.18083445, ...,  0.08746865,
#            0.05109295,         nan]),
#    array([ 0.2649555 ,  0.27422076,  0.28546658, ...,  0.46763313,
#            0.45296659,         nan]),
#    array([ 0.08489815,  0.06470941,  0.06041105, ...,  0.        ,
#            0.        ,         nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([ 0.57508197,  0.53843214,  0.52865311, ...,  0.20512479,
#            0.17414633,         nan]),
#    array([ 0.03085196,  0.02612118,  0.03367083, ...,  0.2670721 ,
#            0.31426693,         nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([ 0.10726134,  0.09284495,  0.0703887 , ...,  1.53802547,
#            1.49930501,         nan]),
#    array([ 0.10298842,  0.11139212,  0.10756547, ...,  0.22142937,
#            0.10684557,         nan]),
#    array([ 0.64961822,  0.65664959,  0.65416567, ...,  0.32152523,
#                   nan,         nan]),
#    array([ 0.01715314,  0.02771943,  0.0452509 , ...,  0.00985634,
#            0.00998861,         nan]),
#    array([ 0.09588772,  0.08927039,  0.09367214, ...,  0.61932341,
#            0.62020415,         nan]),
#    array([ 0.        ,  0.        ,  0.        , ...,  0.06957897,
#                   nan,         nan])],
#   'hg4': [array([ 0.74921441,  0.73180227,  0.72324653, ...,  0.78245875,
#            0.8056441 ,         nan]),
#    array([ 0.57605531,  0.61310937,  0.59820321, ...,  0.11712632,
#            0.70990226,         nan]),
#    array([ 0.22567372,  0.2384532 ,  0.26832281, ...,  0.01697236,
#            0.        ,         nan]),
#    array([ 0.67348321,  0.71384194,  0.70615546, ...,  1.18673639,
#            1.21553029,         nan]),
#    array([ 0.38662409,  0.37119461,  0.3509479 , ...,  0.        ,
#            0.1776571 ,         nan]),
#    array([ 0.27948847,  0.28158379,  0.31801963, ...,  0.22791817,
#            0.20930918,         nan]),
#    array([ 1.50665611,  1.52610892,  1.52368001, ...,  2.02918679,
#            2.01177596,         nan]),
#    array([ 0.27525216,  0.21880278,  0.23287571, ...,  0.46878704,
#            0.4588452 ,         nan]),
#    array([ 1.3056716 ,  1.31068801,  1.33138772, ...,  1.19770025,
#            1.20709078,         nan]),
#    array([ 0.8926344 ,  0.90995765,  0.88181255, ...,  0.25146909,
#            0.1649736 ,         nan]),
#    array([ 0.73259879,  0.71534445,  0.70488366, ...,  0.        ,
#            0.47731299,         nan]),
#    array([ 0.13984821,  0.14442883,  0.14056501, ...,  0.        ,
#                   nan,         nan]),
#    array([ 0.23488833,  0.27614519,  0.2236355 , ...,  0.03571364,
#            0.01367361,         nan]),
#    array([ 0.72689948,  0.73177601,  0.72822773, ...,  0.58736716,
#            0.60860669,         nan]),
#    array([ 0.56895673,  0.48706352,  0.49398776, ...,  0.18225287,
#                   nan,         nan])],
#   'i1': [array([ 0.10627095,  0.10709779,  0.10743586, ...,  0.11035317,
#            0.11423092,         nan]),
#    array([ 0.31362791,  0.37191522,  0.34161794, ...,  0.01192914,
#            2.03708112,         nan]),
#    array([ 0.29299761,  0.29015629,  0.23565218, ...,  0.09514246,
#            0.06338585,         nan]),
#    array([ 0.16770294,  0.16612319,  0.17207308, ...,  0.40364569,
#            0.3817299 ,         nan]),
#    array([ 0.59182375,  0.5493233 ,  0.5184035 , ...,  0.        ,
#            0.29888325,         nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([ 0.3942112 ,  0.3791564 ,  0.36130155, ...,  0.43252507,
#            0.41139302,         nan]),
#    array([ 0.        ,  0.        ,  0.        , ...,  0.16140155,
#            0.16187557,         nan]),
#    array([ 0.00030346,  0.00058881,  0.01517379, ...,  0.07760298,
#            0.06043704,         nan]),
#    array([ 0.        ,  0.        ,  0.        , ...,  0.77341043,
#            0.70688721,         nan]),
#    array([ 0.10722313,  0.1089107 ,  0.1089574 , ...,  0.11009297,
#            0.1400711 ,         nan]),
#    array([ 0.17074987,  0.16671362,  0.16433628, ...,  0.50690379,
#                   nan,         nan]),
#    array([ 0.0714231 ,  0.06531831,  0.06801348, ...,  0.04787762,
#            0.05446397,         nan]),
#    array([ 0.2530194 ,  0.29257864,  0.32218794, ...,  0.17528752,
#            0.17087128,         nan]),
#    array([ 0.00024639,  0.00047449,  0.00798449, ...,  0.04297664,
#                   nan,         nan])],
#   'i2': [array([ 0.4849444 ,  0.49073119,  0.50399742, ...,  0.66136286,
#            0.67032304,         nan]),
#    array([ 0.37612833,  0.38531439,  0.39361177, ...,  0.03392856,
#            0.8646407 ,         nan]),
#    array([ 0.35045966,  0.35531167,  0.34767563, ...,  0.29828422,
#            0.32140139,         nan]),
#    array([ 0.05370913,  0.01127459,  0.00129163, ...,  0.56198331,
#            0.54292055,         nan]),
#    array([ 0.63140393,  0.61140052,  0.61922179, ...,  0.        ,
#            0.67755838,         nan]),
#    array([ 0.55091864,  0.54337338,  0.53968228, ...,  0.86086678,
#            0.90193523,         nan]),
#    array([ 0.40098144,  0.39000609,  0.40834494, ...,  0.8416866 ,
#            0.82451779,         nan]),
#    array([ 1.1004295 ,  1.13510802,  1.13212886, ...,  1.14818507,
#            1.1709378 ,         nan]),
#    array([ 0.64687855,  0.62767058,  0.63669328, ...,  0.87602791,
#            0.90254271,         nan]),
#    array([ 0.38215851,  0.39324239,  0.38721288, ...,  0.30704256,
#            0.32765847,         nan]),
#    array([ 0.02263496,  0.03893114,  0.04022591, ...,  0.12309979,
#            0.22403117,         nan]),
#    array([ 0.63005272,  0.62402887,  0.61252421, ...,  0.7531202 ,
#                   nan,         nan]),
#    array([ 0.5356716 ,  0.5340125 ,  0.50761863, ...,  0.00289196,
#            0.01880638,         nan]),
#    array([ 0.53035687,  0.52289286,  0.52112173, ...,  0.52306764,
#            0.536198  ,         nan]),
#    array([  0.,   0.,   0., ...,   0.,  nan,  nan])],
#   'iii1': [array([ 0.02147637,  0.01910448,  0.02123587, ...,  0.00627073,
#            0.00945545,         nan]),
#    array([ 0.1362554 ,  0.14160789,  0.14579935, ...,  0.        ,
#            0.42908811,         nan]),
#    array([ 0.        ,  0.        ,  0.        , ...,  0.00627436,
#            0.        ,         nan]),
#    array([ 0.08990177,  0.09289793,  0.10681972, ...,  0.09920797,
#            0.08902718,         nan]),
#    array([  0.00000000e+00,   7.04711304e-05,   0.00000000e+00, ...,
#             0.00000000e+00,   0.00000000e+00,              nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([ 0.08715799,  0.09335044,  0.08836381, ...,  0.13279474,
#            0.12206468,         nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([ 0.0260047 ,  0.02618566,  0.02507916, ...,  0.09366296,
#            0.10944278,         nan]),
#    array([ 0.      ,  0.      ,  0.      , ...,  0.203118,       nan,
#                 nan]),
#    array([ 0.00662071,  0.00661477,  0.01191935, ...,  0.2479545 ,
#            0.15663005,         nan]),
#    array([ 0.04665683,  0.03419657,  0.02660928, ...,  0.        ,
#            0.        ,         nan]),
#    array([ 0.        ,  0.        ,  0.        , ...,  0.04599454,
#                   nan,         nan])],
#   'iii24': [array([ 0.00795581,  0.00073665,  0.0059153 , ...,  0.17044864,
#            0.26582893,         nan]),
#    array([ 0.0462896 ,  0.00428608,  0.        , ...,  0.00227921,
#            0.        ,         nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([ 0.2109936 ,  0.22418226,  0.19595182, ...,  0.        ,
#            0.07872311,         nan]),
#    array([ 0.33475573,  0.3071407 ,  0.31739991, ...,  0.27617712,
#            0.28997175,         nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([ 0.03763158,  0.00675898,  0.04516427, ...,  0.27432616,
#            0.29183959,         nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([ 0.26820593,  0.33609742,  0.26658766, ...,  0.29286455,
#            0.13570214,         nan]),
#    array([  0.,   0.,   0., ...,   0.,  nan,  nan]),
#    array([ 0.68694338,  0.72622076,  0.77519505, ...,  0.21273381,
#            0.0651308 ,         nan]),
#    array([ 0.04986797,  0.04277232,  0.06563863, ...,  0.00216978,
#            0.05207107,         nan]),
#    array([ 0.05427858,  0.02402583,  0.01016987, ...,  0.22402581,
#                   nan,         nan])],
#   'iii3': [array([ 0.58206162,  0.5851099 ,  0.56561789, ...,  0.66942759,
#            0.65607172,         nan]),
#    array([ 0.63741766,  0.64616516,  0.68517039, ...,  0.        ,
#            1.39554696,         nan]),
#    array([ 0.7724159 ,  0.80890814,  0.77504086, ...,  0.66071567,
#            0.65915812,         nan]),
#    array([ 1.5622715 ,  1.57470407,  1.59507322, ...,  1.15473155,
#            1.13742552,         nan]),
#    array([ 0.91043331,  0.98004637,  1.05658437, ...,  0.        ,
#            1.54937457,         nan]),
#    array([ 1.25796733,  1.26851826,  1.23923407, ...,  1.32499376,
#            1.34762243,         nan]),
#    array([ 2.04297108,  2.03576798,  2.02493801, ...,  2.19761645,
#            2.20651254,         nan]),
#    array([ 2.74763034,  2.73486096,  2.7475362 , ...,  1.76233016,
#            1.72605661,         nan]),
#    array([ 0.95378116,  0.94600452,  0.99412609, ...,  1.34350634,
#            1.29392816,         nan]),
#    array([ 2.13695244,  2.11896547,  2.11995517, ...,  0.84014622,
#            0.7838333 ,         nan]),
#    array([ 2.18919852,  2.11479442,  2.15868275, ...,  2.46717037,
#            2.12810342,         nan]),
#    array([ 0.86044847,  0.78851233,  0.71310548, ...,  1.27841756,
#                   nan,         nan]),
#    array([ 1.30388049,  1.31150273,  1.39726454, ...,  0.13574717,
#            0.16625922,         nan]),
#    array([ 1.51604664,  1.56811342,  1.50635384, ...,  1.50127815,
#            1.54116731,         nan]),
#    array([ 0.09550672,  0.00852779,  0.        , ...,  0.00390563,
#                   nan,         nan])],
#   'pr': [array([ 0.31420695,  0.31470478,  0.31109999, ...,  0.23722418,
#            0.25334621,         nan]),
#    array([ 0.57255217,  0.56920609,  0.57262486, ...,  0.04220469,
#            0.91183527,         nan]),
#    array([ 0.47895798,  0.51202254,  0.49936534, ...,  0.54813965,
#            0.43430946,         nan]),
#    array([ 0.64660257,  0.63318323,  0.61070831, ...,  0.74542205,
#            0.77639833,         nan]),
#    array([ 0.53355144,  0.5553122 ,  0.52900453, ...,  0.32948844,
#            0.35782297,         nan]),
#    array([ 0.22022927,  0.21915764,  0.22686013, ...,  0.11356416,
#            0.11238879,         nan]),
#    array([ 0.        ,  0.        ,  0.        , ...,  0.09799462,
#            0.09111357,         nan]),
#    array([ 0.03889514,  0.04550445,  0.04582541, ...,  0.31709167,
#            0.31074916,         nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([ 0.        ,  0.        ,  0.        , ...,  0.01142011,
#            0.0034484 ,         nan]),
#    array([ 0.16373356,  0.16118681,  0.15841994, ...,  0.21342895,
#            0.2211637 ,         nan]),
#    array([  0.,   0.,   0., ...,   0.,  nan,  nan]),
#    array([ 0.05253782,  0.04922091,  0.05119464, ...,  0.19509759,
#            0.11304157,         nan]),
#    array([ 0.2228753 ,  0.22891106,  0.22315327, ...,  0.16654922,
#            0.16195912,         nan]),
#    array([ 0.       ,  0.       ,  0.       , ...,  0.0767081,        nan,
#                  nan])],
#   'tpd': [array([ 0.09514909,  0.09798453,  0.10440885, ...,  0.08624421,
#            0.09047841,         nan]),
#    array([ 0.24181526,  0.24995916,  0.24125009, ...,  0.00364546,
#            0.33306002,         nan]),
#    array([ 0.28781758,  0.29722672,  0.29126024, ...,  0.23849033,
#            0.22352696,         nan]),
#    array([ 0.26223662,  0.26300957,  0.2627811 , ...,  0.20816314,
#            0.2227083 ,         nan]),
#    array([ 0.        ,  0.        ,  0.        , ...,  0.        ,
#            0.04478152,         nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([ 0.26746117,  0.25868872,  0.25386423, ...,  0.2481218 ,
#            0.25064724,         nan]),
#    array([ 0.10049513,  0.10268483,  0.11400347, ...,  0.20753179,
#            0.20619105,         nan]),
#    array([ 0.01939213,  0.02152788,  0.01294596, ...,  0.03675153,
#            0.0233754 ,         nan]),
#    array([ 0.1692289 ,  0.16958898,  0.18173165, ...,  0.29063152,
#            0.3030516 ,         nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([ 0.21725487,  0.21674387,  0.2251043 , ...,  0.26027212,
#                   nan,         nan]),
#    array([ 0.02075896,  0.01261014,  0.01394357, ...,  0.        ,
#            0.        ,         nan]),
#    array([ 0.01633667,  0.01269961,  0.00698978, ...,  0.04551157,
#            0.03442089,         nan]),
#    array([  0.,   0.,   0., ...,   0.,  nan,  nan])],
#   'tpv': [array([ 0.17554345,  0.17778681,  0.17434024, ...,  0.17392375,
#            0.18250846,         nan]),
#    array([ 0.03100983,  0.00283469,  0.00422524, ...,  0.        ,
#            0.        ,         nan]),
#    array([ 0.5506522 ,  0.54352757,  0.53670504, ...,  0.54068261,
#            0.5121096 ,         nan]),
#    array([ 0.52021707,  0.48486332,  0.47246002, ...,  0.68665894,
#            0.66396722,         nan]),
#    array([ 0.48137148,  0.50502805,  0.49004877, ...,  0.        ,
#            0.50462577,         nan]),
#    array([ 0.30102966,  0.29832296,  0.29221238, ...,  0.42285764,
#            0.39528159,         nan]),
#    array([ 0.38216979,  0.34817153,  0.34891783, ...,  0.39250985,
#            0.39986988,         nan]),
#    array([ 0.55810246,  0.54484549,  0.51861738, ...,  0.56217926,
#            0.57211932,         nan]),
#    array([ 0.14045425,  0.15210933,  0.16665275, ...,  0.34466843,
#            0.34725401,         nan]),
#    array([ 0.4916784 ,  0.46746303,  0.43862576, ...,  0.43318579,
#            0.43525048,         nan]),
#    array([ 0.35064844,  0.351201  ,  0.33562448, ...,  0.37946526,
#            0.36396445,         nan]),
#    array([ 0.        ,  0.        ,  0.        , ...,  0.28164894,
#                   nan,         nan]),
#    array([ 0.20833187,  0.21283796,  0.21739288, ...,  0.01227941,
#            0.01348244,         nan]),
#    array([ 0.57129729,  0.56527401,  0.56811249, ...,  0.50456967,
#            0.50599153,         nan]),
#    array([ 0.        ,  0.        ,  0.        , ...,  0.00582984,
#                   nan,         nan])],
#   'ttm': [array([ 0.02292352,  0.02219137,  0.02200576, ...,  0.02550711,
#            0.02536642,         nan]),
#    array([ 0.0468422 ,  0.04563747,  0.04525151, ...,  0.01338695,
#            0.00015883,         nan]),
#    array([ 0.01160103,  0.01528797,  0.0126083 , ...,  0.00642438,
#            0.00295421,         nan]),
#    array([ 0.06902418,  0.0677371 ,  0.06665956, ...,  0.05655686,
#            0.05641926,         nan]),
#    array([ 0.01238924,  0.01136049,  0.01200857, ...,  0.        ,
#            0.000434  ,         nan]),
#    array([ 0.02175032,  0.02255781,  0.02281582, ...,  0.02252014,
#            0.02055544,         nan]),
#    array([ 0.07791965,  0.07850599,  0.07782285, ...,  0.08150833,
#            0.07976854,         nan]),
#    array([ 0.02621461,  0.02700537,  0.02636108, ...,  0.04604629,
#            0.0442164 ,         nan]),
#    array([ 0.02416781,  0.02500204,  0.02954144, ...,  0.02337804,
#            0.02573694,         nan]),
#    array([ 0.03403459,  0.03129637,  0.02959744, ...,  0.04424799,
#            0.0426733 ,         nan]),
#    array([ 0.06115403,  0.06187577,  0.06018863, ...,  0.0684891 ,
#            0.06985014,         nan]),
#    array([ 0.03174184,  0.03272642,  0.0314783 , ...,  0.08953981,
#                   nan,         nan]),
#    array([ 0.06159236,  0.06199499,  0.06235867, ...,  0.02394961,
#            0.01848395,         nan]),
#    array([ 0.0471795 ,  0.04802881,  0.04957957, ...,  0.045777  ,
#            0.04542301,         nan]),
#    array([ 0.00663501,  0.00686591,  0.00671398, ...,  0.00748351,
#                   nan,         nan])],
#   'wb_frequency': [array([ 191.56532087,  190.91532962,  190.84185648, ...,  194.74804957,
#            199.1182207 ,           nan]),
#    array([  1.80195175e+02,   1.67568327e+02,   1.67502818e+02, ...,
#             4.39034315e-02,   1.96410590e+02,              nan]),
#    array([ 178.31718321,  175.76982572,  174.01490188, ...,  177.97834526,
#            170.65015441,           nan]),
#    array([ 194.08624938,  196.28027195,  196.66791812, ...,  212.18736301,
#            210.7896062 ,           nan]),
#    array([  1.68090706e+02,   1.70750893e+02,   1.70726292e+02, ...,
#             4.38899871e-02,   1.78942153e+02,              nan]),
#    array([ 183.04469866,  180.47618113,  178.83862677, ...,  198.21908384,
#            197.20855453,           nan]),
#    array([ 192.4009392 ,  191.0896641 ,  190.61578584, ...,  197.31514567,
#            197.94951154,           nan]),
#    array([ 206.25059887,  207.54184233,  207.47266218, ...,  210.03868252,
#            209.82284795,           nan]),
#    array([ 181.61393321,  180.44452254,  187.07481125, ...,  202.21396263,
#            204.36688407,           nan]),
#    array([ 225.05551421,  225.29537831,  225.48581952, ...,  219.33265737,
#            222.14462429,           nan]),
#    array([ 216.86411286,  217.02565529,  218.69757453, ...,  213.1854521 ,
#            214.89094641,           nan]),
#    array([ 198.3648059 ,  198.18841761,  197.17184627, ...,  218.43483239,
#                     nan,           nan]),
#    array([ 214.00838026,  214.31017671,  216.67717215, ...,    0.39000343,
#              0.34632977,           nan]),
#    array([ 232.80597472,  230.7697655 ,  230.4176713 , ...,  225.37533279,
#            226.23973015,           nan]),
#    array([ 234.94663317,  192.82377417,  218.27930195, ...,    0.60385471,
#                     nan,           nan])]},
#  'GMR22H05_GFP': {'b1': [array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([ 0.02656301,  0.0226642 ,  0.02416841, ...,  0.01920561,
#            0.01932667,         nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan])],
#   'b2': [array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([ 0.03561377,  0.03059779,  0.02842244, ...,  0.00055071,
#            0.        ,         nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan])],
#   'b3': [array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([ 0.00815689,  0.01497316,  0.01703613, ...,  0.04248051,
#            0.04689433,         nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan])],
#   'hg1': [array([ 0.83207947,  0.8285624 ,  0.42252185, ...,  0.7036026 ,
#            0.67879162,         nan]),
#    array([ 0.        ,  0.        ,  0.        , ...,  0.08313968,
#            0.08894669,         nan]),
#    array([ 1.64060108,  1.48760852,  1.48320623, ...,  0.78868215,
#            0.59350565,         nan])],
#   'hg2': [array([ 2.96046155,  3.1150391 ,  2.8245622 , ...,  2.03792509,
#            1.96787305,         nan]),
#    array([ 0.        ,  0.        ,  0.        , ...,  0.25017359,
#            0.23167832,         nan]),
#    array([ 4.51309791,  4.737873  ,  4.59744177, ...,  3.5610755 ,
#            3.6118278 ,         nan])],
#   'hg3': [array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan])],
#   'hg4': [array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([ 0.        ,  0.        ,  0.00450549, ...,  0.        ,
#            0.        ,         nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan])],
#   'i1': [array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([ 0.0440764 ,  0.04412672,  0.04928821, ...,  0.13182339,
#            0.13074651,         nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan])],
#   'i2': [array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([ 0.04058079,  0.04050242,  0.03482915, ...,  0.08063289,
#            0.07858882,         nan]),
#    array([ 0.        ,  0.        ,  0.        , ...,  0.05851208,
#            0.09225058,         nan])],
#   'iii1': [array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([ 0.00388486,  0.00034688,  0.        , ...,  0.03137169,
#            0.03107631,         nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan])],
#   'iii24': [array([ 1.99125895,  2.00638818,  2.51566194, ...,  2.1125673 ,
#            2.16602368,         nan]),
#    array([ 0.52824651,  0.54797436,  0.5815423 , ...,  0.11227229,
#            0.10981076,         nan]),
#    array([ 0.66843421,  0.9460678 ,  0.99761538, ...,  1.47567506,
#            1.59163845,         nan])],
#   'iii3': [array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([ 0.07534284,  0.08231555,  0.08534369, ...,  0.07480166,
#            0.0724468 ,         nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan])],
#   'pr': [array([ 0.15394141,  0.16715198,  0.1507247 , ...,  0.10717445,
#            0.10854139,         nan]),
#    array([ 0.03486171,  0.02809401,  0.03651361, ...,  0.30778163,
#            0.30474034,         nan]),
#    array([ 0.13277427,  0.12251729,  0.11652632, ...,  0.        ,
#            0.        ,         nan])],
#   'tpd': [array([ 0.48083493,  0.50607662,  0.45016517, ...,  0.37992629,
#            0.36908224,         nan]),
#    array([ 0.02120845,  0.02682654,  0.01925588, ...,  0.04951755,
#            0.04879812,         nan]),
#    array([ 1.26360486,  1.20629154,  1.15234657, ...,  1.3669307 ,
#            1.38625051,         nan])],
#   'tpv': [array([ 0.90534329,  0.9751761 ,  0.94270154, ...,  0.85377423,
#            0.85406964,         nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([ 1.0046983 ,  0.93624948,  0.88720328, ...,  0.48964729,
#            0.43761088,         nan])],
#   'ttm': [array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([ 0.0025818 ,  0.00316415,  0.0030363 , ...,  0.00138183,
#            0.0019699 ,         nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan])],
#   'wb_frequency': [array([ 210.12245547,  211.27737395,  212.826876  , ...,  218.12857644,
#            219.24693245,           nan]),
#    array([ 213.741374  ,  212.95999824,  214.01722729, ...,  206.59242794,
#            207.35557303,           nan]),
#    array([ 190.88593554,  188.22984452,  188.03963515, ...,  199.37065984,
#            200.69623925,           nan])]},
#  'GMR29E05': {'b1': [array([ 1.78870756,  1.77645955,  1.77808282, ...,  1.42866569,
#            1.40098556,         nan]),
#    array([ 1.8870652 ,  1.88735796,  1.89074478, ...,  1.89836398,
#            1.93308701,         nan]),
#    array([ 1.82950581,  1.84651317,  1.84608407, ...,  0.4299528 ,
#            1.62176007,         nan]),
#    array([ 1.63934432,  1.63282886,  1.62902936, ...,  1.60444933,
#            1.61188725,         nan]),
#    array([ 1.53181889,  1.53318901,  1.53272232, ...,  1.48429251,
#            1.46638142,         nan]),
#    array([ 1.17244255,  1.17595184,  1.17731462, ...,  1.17109652,
#            1.18140406,         nan]),
#    array([ 1.73592349,  1.74006346,  1.75241896, ...,  1.71695001,
#            1.73019328,         nan])],
#   'b2': [array([ 0.22518129,  0.22457385,  0.22338793, ...,  0.14859835,
#            0.158517  ,         nan]),
#    array([ 0.19562099,  0.19233969,  0.19046297, ...,  0.19198723,
#            0.19961498,         nan]),
#    array([ 0.10510145,  0.11436682,  0.11283982, ...,  0.        ,
#            0.10221111,         nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([ 0.14479191,  0.15498398,  0.15234082, ...,  0.12296202,
#            0.10987218,         nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan])],
#   'b3': [array([ 0.47557452,  0.47901595,  0.46862464, ...,  0.37213527,
#            0.3786561 ,         nan]),
#    array([ 0.6681476 ,  0.65669643,  0.63725842, ...,  0.76591759,
#            0.77290959,         nan]),
#    array([ 0.47697076,  0.49202962,  0.48767567, ...,  0.08444938,
#            0.47906228,         nan]),
#    array([ 0.20251301,  0.19971221,  0.19272929, ...,  0.1750645 ,
#            0.17771977,         nan]),
#    array([ 0.53773374,  0.53476879,  0.53629801, ...,  0.48888438,
#            0.46995169,         nan]),
#    array([ 0.31204699,  0.26694974,  0.29329569, ...,  0.3200958 ,
#            0.32092105,         nan]),
#    array([ 0.33953448,  0.32426488,  0.32985152, ...,  0.24916633,
#            0.24898276,         nan])],
#   'hg1': [array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([ 0.18250486,  0.17610432,  0.16927137, ...,  0.11918299,
#            0.13028362,         nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan])],
#   'hg2': [array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan])],
#   'hg3': [array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([ 0.04683472,  0.06254649,  0.09791977, ...,  0.05272633,
#            0.01804507,         nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([ 0.20634724,  0.19488808,  0.18934276, ...,  0.13008937,
#            0.12677665,         nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan])],
#   'hg4': [array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([ 0.12652757,  0.12859139,  0.12479756, ...,  0.133902  ,
#            0.13107551,         nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([ 0.10390822,  0.09355958,  0.09236183, ...,  0.07764519,
#            0.0832855 ,         nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan])],
#   'i1': [array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([ 0.08818068,  0.09253598,  0.09710592, ...,  0.0373378 ,
#            0.04210765,         nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan])],
#   'i2': [array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan])],
#   'iii1': [array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([ 0.00926993,  0.00865539,  0.01334064, ...,  0.        ,
#            0.        ,         nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([ 0.07978914,  0.07974173,  0.07988368, ...,  0.03050825,
#            0.02889129,         nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan])],
#   'iii24': [array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan])],
#   'iii3': [array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([ 0.0416692 ,  0.03982285,  0.03885607, ...,  0.03891598,
#            0.02481733,         nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([ 0.06726017,  0.07436647,  0.07059474, ...,  0.04377537,
#            0.03873723,         nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan])],
#   'pr': [array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([ 0.05847334,  0.06135614,  0.05972306, ...,  0.01449658,
#            0.00439086,         nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([ 0.21339477,  0.21604982,  0.22177059, ...,  0.09906439,
#            0.1056798 ,         nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan])],
#   'tpd': [array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan])],
#   'tpv': [array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan])],
#   'ttm': [array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan])],
#   'wb_frequency': [array([ 195.06410825,  195.80157799,  194.90600704, ...,  192.81277439,
#            195.38169356,           nan]),
#    array([ 204.79755409,  205.37759336,  206.88101405, ...,  212.87866048,
#            213.52444237,           nan]),
#    array([ 185.36770366,  188.77411824,  189.73309858, ...,  201.54118261,
#            202.72255428,           nan]),
#    array([ 187.06117188,  189.35405038,  188.72998486, ...,  187.75939652,
#            187.89200296,           nan]),
#    array([ 180.93643468,  182.65020634,  184.84012718, ...,  185.01215978,
#            182.82283218,           nan]),
#    array([ 216.85307135,  216.49419789,  217.50154954, ...,  209.36652953,
#            212.22593756,           nan]),
#    array([ 212.75343633,  213.14911584,  212.70976853, ...,  210.77105867,
#            210.39896026,           nan])]},
#  'GMR29E05_GFP': {'b1': [array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([ 0.00939166,  0.01460492,  0.00667002, ...,  0.        ,
#            0.        ,         nan])],
#   'b2': [array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan])],
#   'b3': [array([ 0.15089028,  0.15684062,  0.14073894, ...,  0.27445861,
#            0.265031  ,         nan]),
#    array([ 0.04646598,  0.06935899,  0.10441433, ...,  0.03084573,
#            0.05460228,         nan])],
#   'hg1': [array([ 0.73166038,  0.74790017,  0.76439138, ...,  0.10232855,
#            0.10453944,         nan]),
#    array([ 0.33052714,  0.33883792,  0.3425349 , ...,  0.08240275,
#            0.07953123,         nan])],
#   'hg2': [array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan])],
#   'hg3': [array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan])],
#   'hg4': [array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([ 0.28201594,  0.23898666,  0.27469552, ...,  0.39208328,
#            0.3845879 ,         nan])],
#   'i1': [array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([ 0.        ,  0.        ,  0.        , ...,  0.00017203,
#            0.        ,         nan])],
#   'i2': [array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan])],
#   'iii1': [array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan])],
#   'iii24': [array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan])],
#   'iii3': [array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan])],
#   'pr': [array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan])],
#   'tpd': [array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan])],
#   'tpv': [array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan])],
#   'ttm': [array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan])],
#   'wb_frequency': [array([ 191.70078666,  190.28544499,  188.76658568, ...,  203.14205728,
#            202.51690219,           nan]),
#    array([ 209.23631776,  209.34391298,  210.14543786, ...,  217.06938952,
#            217.11607034,           nan])]},
#  'GMR31E10': {'b1': [array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([ 0.12459713,  0.13956465,  0.10758793, ...,  0.08263223,
#            0.08177981,         nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([ 0.16993575,  0.1695115 ,  0.16546563, ...,  0.12586298,
#            0.12718538,         nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan])],
#   'b2': [array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([ 0.05336844,  0.06300824,  0.03993291, ...,  0.01294264,
#            0.01403404,         nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([ 0.0844359 ,  0.0868588 ,  0.08208894, ...,  0.04447665,
#            0.0469876 ,         nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan])],
#   'b3': [array([ 0.21561872,  0.21225739,  0.21381699, ...,  0.19205309,
#            0.13992673,         nan]),
#    array([ 0.35713746,  0.36479708,  0.35685992, ...,  0.34900657,
#            0.34268214,         nan]),
#    array([ 0.01337782,  0.01462228,  0.04180524, ...,  0.        ,
#            0.        ,         nan]),
#    array([ 0.39989339,  0.40239445,  0.40264823, ...,  0.36080251,
#            0.36399   ,         nan]),
#    array([ 0.1652389 ,  0.16359486,  0.16395007, ...,  0.04022236,
#            0.09765645,         nan]),
#    array([ 0.16476249,  0.16463754,  0.1585386 , ...,  0.12665432,
#            0.13375888,         nan])],
#   'hg1': [array([ 0.        ,  0.        ,  0.        , ...,  0.15713993,
#            0.        ,         nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([ 0.00585951,  0.00904615,  0.00168732, ...,  0.        ,
#            0.        ,         nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan])],
#   'hg2': [array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan])],
#   'hg3': [array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([ 0.11738149,  0.23271189,  0.22412889, ...,  0.        ,
#            0.        ,         nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([ 0.18970242,  0.19803043,  0.06239886, ...,  0.09005272,
#            0.08636434,         nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan])],
#   'hg4': [array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
# ...
#   'ttm': [array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan])],
#   'wb_frequency': [array([ 168.9233592 ,  150.46618139,  142.86493774, ...,  167.29760501,
#            169.63881296,           nan]),
#    array([ 144.79283459,  147.93223654,  148.77151195, ...,  147.4272005 ,
#            187.9558618 ,           nan])]},
#  'GMR39E01_GFP': {'b1': [],
#   'b2': [],
#   'b3': [],
#   'hg1': [],
#   'hg2': [],
#   'hg3': [],
#   'hg4': [],
#   'i1': [],
#   'i2': [],
#   'iii1': [],
#   'iii24': [],
#   'iii3': [],
#   'pr': [],
#   'tpd': [],
#   'tpv': [],
#   'ttm': [],
#   'wb_frequency': []},
#  'GMR74F03': {'b1': [array([ 0.29794111,  0.29270407,  0.29381181, ...,  0.29306311,
#            0.29390005,         nan]),
#    array([ 0.73759265,  0.73362767,  0.73404297, ...,  0.67445753,
#            0.67092266,         nan]),
#    array([ 0.67433097,  0.65712156,  0.64819362, ...,  0.43369218,
#            0.50348658,         nan])],
#   'b2': [array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([ 0.04812129,  0.04665495,  0.04400115, ...,  0.        ,
#            0.00303747,         nan])],
#   'b3': [array([ 0.4668525 ,  0.45560477,  0.43123113, ...,  0.62233637,
#            0.60955371,         nan]),
#    array([ 1.02238015,  0.99948653,  1.01594006, ...,  0.88711355,
#            0.88448556,         nan]),
#    array([ 1.03878987,  1.04081821,  1.04644553, ...,  0.68628264,
#            0.83925254,         nan])],
#   'hg1': [array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([ 0.80216704,  0.89451143,  0.98680717, ...,  0.1690907 ,
#            0.63900741,         nan])],
#   'hg2': [array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan])],
#   'hg3': [array([ 0.        ,  0.        ,  0.        , ...,  0.01083241,
#            0.01552604,         nan]),
#    array([ 0.22788197,  0.2430305 ,  0.23806968, ...,  0.14924393,
#            0.1546996 ,         nan]),
#    array([ 0.        ,  0.        ,  0.        , ...,  0.51163546,
#            0.6018023 ,         nan])],
#   'hg4': [array([ 0.        ,  0.        ,  0.02426314, ...,  0.29448467,
#            0.29947819,         nan]),
#    array([ 0.66562685,  0.66521994,  0.6818857 , ...,  0.96499238,
#            0.95755121,         nan]),
#    array([ 0.85369648,  0.82269371,  0.84215988, ...,  0.59364679,
#            0.67918518,         nan])],
#   'i1': [array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([ 0.0090525 ,  0.00112374,  0.        , ...,  0.01745085,
#            0.01799257,         nan]),
#    array([ 0.21101917,  0.24264268,  0.26464114, ...,  0.        ,
#            0.0187558 ,         nan])],
#   'i2': [array([ 0.        ,  0.        ,  0.        , ...,  0.19655632,
#            0.19810854,         nan]),
#    array([ 0.01220921,  0.02728995,  0.03576458, ...,  0.26141732,
#            0.2692291 ,         nan]),
#    array([ 0.2968703 ,  0.30293597,  0.30048637, ...,  0.52566068,
#            0.52381112,         nan])],
#   'iii1': [array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan])],
#   'iii24': [array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan])],
#   'iii3': [array([ 1.20075599,  1.2066058 ,  1.22533678, ...,  1.2486695 ,
#            1.24411049,         nan]),
#    array([ 0.34563433,  0.38047384,  0.49233816, ...,  0.96348336,
#            0.98600159,         nan]),
#    array([ 0.92680816,  0.87417898,  0.82330286, ...,  1.31537809,
#            1.44373724,         nan])],
#   'pr': [array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan])],
#   'tpd': [array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan])],
#   'tpv': [array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan])],
#   'ttm': [array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([ 0.01104863,  0.01148958,  0.01150053, ...,  0.00267788,
#            0.00313162,         nan])],
#   'wb_frequency': [array([ 200.35933282,  200.39003124,  198.9253687 , ...,  198.47755382,
#            198.06125884,           nan]),
#    array([ 222.46658206,  222.93097218,  223.0407477 , ...,  223.92923399,
#            223.26254783,           nan]),
#    array([ 185.86629399,  186.38708901,  187.8259842 , ...,  194.92489528,
#            201.04753791,           nan])]},
#  'GMR74F03_GFP': {'b1': [array([ 0.09675142,  0.09386666,  0.07519811, ...,  0.05425041,
#            0.05147981,         nan])],
#   'b2': [array([  0.,   0.,   0., ...,   0.,   0.,  nan])],
#   'b3': [array([ 0.52662614,  0.54477513,  0.52047567, ...,  0.41758528,
#            0.41348051,         nan])],
#   'hg1': [array([ 3.51164766,  3.47958441,  3.42265925, ...,  2.8040507 ,
#            2.92954112,         nan])],
#   'hg2': [array([ nan,  nan,  nan, ...,  nan,  nan,  nan])],
#   'hg3': [array([ 0.51373918,  0.53268485,  0.55261648, ...,  0.52347503,
#            0.54950135,         nan])],
#   'hg4': [array([  0.,   0.,   0., ...,   0.,   0.,  nan])],
#   'i1': [array([  0.,   0.,   0., ...,   0.,   0.,  nan])],
#   'i2': [array([ 0.02833276,  0.02802579,  0.00865898, ...,  0.        ,
#            0.        ,         nan])],
#   'iii1': [array([  0.,   0.,   0., ...,   0.,   0.,  nan])],
#   'iii24': [array([ nan,  nan,  nan, ...,  nan,  nan,  nan])],
#   'iii3': [array([ 0.        ,  0.        ,  0.        , ...,  0.01322475,
#            0.0040687 ,         nan])],
#   'pr': [array([ 0.24793331,  0.24812601,  0.25207973, ...,  0.16678362,
#            0.16786257,         nan])],
#   'tpd': [array([ nan,  nan,  nan, ...,  nan,  nan,  nan])],
#   'tpv': [array([ nan,  nan,  nan, ...,  nan,  nan,  nan])],
#   'ttm': [array([ 0.11463902,  0.11800798,  0.11326613, ...,  0.12248489,
#            0.12060471,         nan])],
#   'wb_frequency': [array([ 210.29787287,  211.43587339,  212.97634335, ...,  218.10606848,
#            218.95866895,           nan])]},
#  'GMR75B06': {'b1': [array([ 0.30259711,  0.30669992,  0.31528839, ...,  0.28231054,
#            0.28574635,         nan]),
#    array([ 0.35938791,  0.35439421,  0.35508779, ...,  0.35633842,
#            0.35627601,         nan]),
#    array([ 0.28406147,  0.28508955,  0.2844615 , ...,  0.25768083,
#            0.25646573,         nan]),
#    array([ 0.29648444,  0.29088928,  0.29409127, ...,  0.23207861,
#            0.24872714,         nan])],
#   'b2': [array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan])],
#   'b3': [array([ 0.7152418 ,  0.71599987,  0.69951766, ...,  0.74634354,
#            0.73864732,         nan]),
#    array([ 0.95992483,  0.98673489,  0.99708218, ...,  0.88819503,
#            0.88622586,         nan]),
#    array([ 0.4851494 ,  0.49107638,  0.49831556, ...,  0.52153687,
#            0.52322506,         nan]),
#    array([ 0.5231852 ,  0.51885116,  0.51786035, ...,  0.63215951,
#            0.63111632,         nan])],
#   'hg1': [array([ 0.        ,  0.        ,  0.        , ...,  0.00077897,
#            0.        ,         nan]),
#    array([ 0.        ,  0.        ,  0.        , ...,  0.07793456,
#            0.086153  ,         nan]),
#    array([ 0.        ,  0.        ,  0.        , ...,  0.00380334,
#            0.00120715,         nan]),
#    array([ 0.        ,  0.        ,  0.        , ...,  0.12009417,
#            0.12395258,         nan])],
#   'hg2': [array([ 0.30952358,  0.27318059,  0.24021309, ...,  0.        ,
#            0.        ,         nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([ 0.03187325,  0.00287235,  0.        , ...,  0.52076743,
#            0.54870308,         nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan])],
#   'hg3': [array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([ 0.        ,  0.        ,  0.        , ...,  0.00140164,
#            0.00029051,         nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan])],
#   'hg4': [array([ 0.41634455,  0.42094414,  0.36484817, ...,  0.14216252,
#            0.14966953,         nan]),
#    array([ 0.97988256,  0.96044164,  0.94870101, ...,  0.94137362,
#            0.99596446,         nan]),
#    array([ 0.32183529,  0.29346581,  0.29666358, ...,  0.41283151,
#            0.39912815,         nan]),
#    array([ 0.58918654,  0.58981212,  0.59518925, ...,  0.66857525,
#            0.71373609,         nan])],
#   'i1': [array([ 0.010453  ,  0.00709165,  0.00781323, ...,  0.01652857,
#            0.01193218,         nan]),
#    array([ 0.0067791 ,  0.02383932,  0.01744173, ...,  0.03403182,
#            0.06289297,         nan]),
#    array([ 0.        ,  0.        ,  0.        , ...,  0.09440049,
#            0.08935275,         nan]),
#    array([ 0.        ,  0.        ,  0.        , ...,  0.03491128,
#            0.04634862,         nan])],
#   'i2': [array([ 0.16921867,  0.16485758,  0.16581598, ...,  0.00122335,
#            0.        ,         nan]),
#    array([ 0.1015348 ,  0.10528499,  0.1211962 , ...,  0.14281218,
#            0.14910192,         nan]),
#    array([ 0.12167396,  0.10984149,  0.08851916, ...,  0.34966585,
#            0.35897635,         nan]),
#    array([ 0.01238245,  0.01094724,  0.0055319 , ...,  0.1015598 ,
#            0.09773079,         nan])],
#   'iii1': [array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([ 0.        ,  0.        ,  0.        , ...,  0.00059786,
#            0.00488201,         nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan])],
#   'iii24': [array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan])],
#   'iii3': [array([ 0.46328718,  0.4782709 ,  0.47085055, ...,  1.22048067,
#            1.21633686,         nan]),
#    array([ 1.06775813,  1.13693662,  1.14394945, ...,  0.94409116,
#            0.94118188,         nan]),
#    array([ 1.02046721,  1.01053135,  1.02474423, ...,  1.13421175,
#            1.12504786,         nan]),
#    array([ 0.83006487,  0.82873034,  0.82846751, ...,  0.39921889,
#            0.63240818,         nan])],
#   'pr': [array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan])],
#   'tpd': [array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan])],
#   'tpv': [array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan])],
#   'ttm': [array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan])],
#   'wb_frequency': [array([ 210.55163106,  207.85297326,  207.00315684, ...,  207.07074535,
#            206.25876384,           nan]),
#    array([ 200.35933282,  200.39003124,  198.9253687 , ...,  198.47755382,
#            198.06125884,           nan]),
#    array([ 185.00848176,  182.89840039,  184.09145498, ...,  195.08978255,
#            196.27100158,           nan]),
#    array([ 193.56386291,  190.60777738,  191.7322842 , ...,  198.29373303,
#            199.64580671,           nan])]},
#  'GMR75B06_GFP': {'b1': [array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan])],
#   'b2': [array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan])],
#   'b3': [array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([ 0.        ,  0.        ,  0.        , ...,  0.00127775,
#            0.00176049,         nan]),
#    array([ 0.01834675,  0.00165337,  0.        , ...,  0.02179441,
#            0.01251365,         nan])],
#   'hg1': [array([ 1.58502443,  1.34296628,  1.46800971, ...,  1.48795003,
#            1.51806194,         nan]),
#    array([ 1.39277161,  1.35050536,  1.38954723, ...,  1.89467532,
#            1.89283415,         nan]),
#    array([ 2.04134494,  2.0843058 ,  2.01786389, ...,  1.45829348,
#            1.47591793,         nan])],
#   'hg2': [array([ 0.94904201,  0.67213754,  1.06307641, ...,  1.85128302,
#            1.74614615,         nan]),
#    array([ 4.83797797,  4.47075795,  4.6092195 , ...,  4.42468884,
#            4.53820583,         nan]),
#    array([ 4.79730512,  4.90907642,  4.57305708, ...,  5.14388882,
#            5.10259635,         nan])],
#   'hg3': [array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan])],
#   'hg4': [array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan])],
#   'i1': [array([ 0.06139535,  0.04740536,  0.04997984, ...,  0.07542739,
#            0.07433097,         nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan])],
#   'i2': [array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan])],
#   'iii1': [array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan])],
#   'iii24': [array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan])],
#   'iii3': [array([  0.,   0.,   0., ...,   0.,   0.,  nan]),
#    array([ 0.18702605,  0.18201696,  0.16080826, ...,  0.25930542,
#            0.22529066,         nan]),
#    array([  0.,   0.,   0., ...,   0.,   0.,  nan])],
#   'pr': [array([ 0.11823715,  0.06991504,  0.10654747, ...,  0.04476863,
#            0.03860237,         nan]),
#    array([ 0.34621025,  0.33115622,  0.34139789, ...,  0.32277096,
#            0.32459091,         nan]),
#    array([ 0.09964893,  0.10029169,  0.0917526 , ...,  0.10863993,
#            0.1100774 ,         nan])],
#   'tpd': [array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan])],
#   'tpv': [array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan]),
#    array([ nan,  nan,  nan, ...,  nan,  nan,  nan])],
#   'ttm': [array([ 0.02269337,  0.02561124,  0.02536245, ...,  0.02327671,
#            0.02485909,         nan]),
#    array([ 0.00937226,  0.01058671,  0.01299422, ...,  0.0114262 ,
#            0.01146897,         nan]),
#    array([  6.43800616e-03,   3.63671265e-03,   1.53460776e-03, ...,
#             3.07257330e-05,   7.24776150e-06,              nan])],
#   'wb_frequency': [array([ 175.87376045,  174.85199862,  174.0968351 , ...,  200.44991599,
#            201.60684606,           nan]),
#    array([ 200.35460691,  205.79024178,  204.90365681, ...,  203.90371006,
#            202.27808285,           nan]),
#    array([ 200.00105015,  197.65445807,  199.33074128, ...,  198.518611  ,
#            198.06671845,           nan])]}}
