# %%
# %pylab inline
# %config InlineBackend.figure_format = 'svg'
import pylab as plb
plb.rcParams['pdf.fonttype'] = 42
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
light_on =  ['/media/FlyDataC/FlyDB/Fly0182/',
            '/media/FlyDataC/FlyDB/Fly0183/',
            '/media/FlyDataC/FlyDB/Fly0184/', 
            '/media/FlyDataC/FlyDB/Fly0185/', 
            '/media/FlyDataC/FlyDB/Fly0186/',
            '/media/FlyDataC/FlyDB/Fly0187/',
            '/media/FlyDataC/FlyDB/Fly0189/']

light_off =  ['/media/FlyDataC/FlyDB/Fly0191/',
              '/media/FlyDataC/FlyDB/Fly0192/',
              '/media/FlyDataC/FlyDB/Fly0193/',
              '/media/FlyDataC/FlyDB/Fly0194/',
              '/media/FlyDataC/FlyDB/Fly0195/',
              '/media/FlyDataC/FlyDB/Fly0196/',
              '/media/FlyDataC/FlyDB/Fly0197/']


flylist = light_on
import cPickle
f = open('/media/FlyDataC/FlyDB/Fly0187/' + 'stim_data.cpkl')
stim = cPickle.load(f)['stim']
f.close()

# %%
lighton_static_test_90 = list()
lighton_static_test_270 = list()

lighton_stripe_test_90 = list()
lighton_stripe_test_270 = list()

lighton_opti_test_90 = list()
lighton_opti_test_270 = list()

for i,rootdir in enumerate(light_on):
    sr = 100*1000
    dt = 1.0/sr
    f = open(rootdir+'T2_trial1_ave_data.cpkl')
    datadict = cPickle.load(f)['rwings']
    times = np.arange(shape(datadict['static_test_90'])[0])*dt
    #axes(ax1)
    #plot(times,rad2deg(datadict['static_test_90']/5),'r',alpha = 0.2)
    lighton_static_test_90.append(rad2deg(datadict['static_test_90']/5))
    #plot(times,rad2deg(datadict['static_test_270']/5),'b',alpha = 0.2)
    lighton_static_test_270.append(rad2deg(datadict['static_test_270']/5))
    #axes(ax2)
    #plot(times,rad2deg(datadict['stripe_test_90']/5),'r',alpha = 0.2)
    lighton_stripe_test_90.append(rad2deg(datadict['stripe_test_90']/5))
    #plot(times,rad2deg(datadict['stripe_test_270']/5),'b',alpha = 0.2)
    lighton_stripe_test_270.append(rad2deg(datadict['stripe_test_270']/5))
    #axes(ax3)
    #plot(times,rad2deg(datadict['opti_test_90']/5),'r',alpha = 0.2)
    lighton_opti_test_90.append(rad2deg(datadict['opti_test_90']/5))
    #plot(times,rad2deg(datadict['opti_test_270']/5),'b',alpha = 0.2)
    lighton_opti_test_270.append(rad2deg(datadict['opti_test_270']/5))

# %%
lightoff_static_test_90 = list()
lightoff_static_test_270 = list()

lightoff_stripe_test_90 = list()
lightoff_stripe_test_270 = list()

lightoff_opti_test_90 = list()
lightoff_opti_test_270 = list()

for i,rootdir in enumerate(light_off):
    sr = 100*1000
    dt = 1.0/sr
    f = open(rootdir+'T2_trial1_ave_data.cpkl')
    datadict = cPickle.load(f)['rwings']
    times = np.arange(shape(datadict['static_test_90'])[0])*dt

    #axes(ax1)
    #plot(times,rad2deg(datadict['static_test_90']/5),'r',alpha = 0.2)
    lightoff_static_test_90.append(rad2deg(datadict['static_test_90']/5))
    #plot(times,rad2deg(datadict['static_test_270']/5),'b',alpha = 0.2)
    lightoff_static_test_270.append(rad2deg(datadict['static_test_270']/5))
    #axes(ax2)
    #plot(times,rad2deg(datadict['stripe_test_90']/5),'r',alpha = 0.2)
    lightoff_stripe_test_90.append(rad2deg(datadict['stripe_test_90']/5))
    #plot(times,rad2deg(datadict['stripe_test_270']/5)1,'b',alpha = 0.2)
    lightoff_stripe_test_270.append(rad2deg(datadict['stripe_test_270']/5))
    #axes(ax3)
    #plot(times,rad2deg(datadict['opti_test_90']/5),'r',alpha = 0.2)
    lightoff_opti_test_90.append(rad2deg(datadict['opti_test_90']/5))
    #plot(times,rad2deg(datadict['opti_test_270']/5),'b',alpha = 0.2)
    lightoff_opti_test_270.append(rad2deg(datadict['opti_test_270']/5))

# %%
#print shape(std(lighton_static_test_90,axis = 0)[::sbs])
#print shape(mean(lighton_static_test_90,axis = 0)[::sbs])

# %%
#shape(lighton_static_test_90)[1]

# %%
figure(figsize = (5,8))

ax0 = subplot(4,2,1)
ax1 = subplot(4,2,3,sharex = ax0)
ax2 = subplot(4,2,5,sharex = ax0)
ax3 = subplot(4,2,7,sharex = ax0)
sbs = 500

axes(ax0)
plot(times[::sbs],stim[::sbs],'r')
plot(times[::sbs],stim[::sbs]*-1,'b')

axes(ax1)
fill_between(times[::sbs],
             mean(lighton_static_test_90,axis = 0)[::sbs]+
             (std(lighton_static_test_90,axis = 0)[::sbs])/sqrt(shape(lighton_static_test_90)[0]),
             mean(lighton_static_test_90,axis = 0)[::sbs]-
             (std(lighton_static_test_90,axis = 0)[::sbs])/sqrt(shape(lighton_static_test_90)[0]),             
             alpha = 0.2,color = 'r',lw = 0)
plot(times[::sbs],mean(lighton_static_test_90,axis = 0)[::sbs],'r')

fill_between(times[::sbs],
             mean(lighton_static_test_270,axis = 0)[::sbs]+
             (std(lighton_static_test_270,axis = 0)[::sbs])/sqrt(shape(lighton_static_test_270)[0]),
             mean(lighton_static_test_270,axis = 0)[::sbs]-
             (std(lighton_static_test_270,axis = 0)[::sbs])/sqrt(shape(lighton_static_test_270)[0]),             
             alpha = 0.2,color = 'b',lw = 0)
plot(times[::sbs],mean(lighton_static_test_270,axis = 0)[::sbs],'b')


#plot(times[::sbs],zeros_like(times)[::sbs],'k')
axes(ax2)
fill_between(times[::sbs],
             mean(lighton_stripe_test_90,axis = 0)[::sbs]+
             (std(lighton_stripe_test_90,axis = 0)[::sbs])/sqrt(shape(lighton_stripe_test_90)[0]),
             mean(lighton_stripe_test_90,axis = 0)[::sbs]-
             (std(lighton_stripe_test_90,axis = 0)[::sbs])/sqrt(shape(lighton_stripe_test_90)[0]),             
             alpha = 0.2,color = 'r',lw = 0)
plot(times[::sbs],mean(lighton_stripe_test_90,axis = 0)[::sbs],'r')

fill_between(times[::sbs],
             mean(lighton_stripe_test_270,axis = 0)[::sbs]+
             (std(lighton_stripe_test_270,axis = 0)[::sbs])/sqrt(shape(lighton_stripe_test_270)[0]),
             mean(lighton_stripe_test_270,axis = 0)[::sbs]-
             (std(lighton_stripe_test_270,axis = 0)[::sbs])/sqrt(shape(lighton_stripe_test_270)[0]),             
             alpha = 0.2,color = 'b',lw = 0)
plot(times[::sbs],mean(lighton_stripe_test_270,axis = 0)[::sbs],'b')


axes(ax3)
fill_between(times[::sbs],
             mean(lighton_opti_test_90,axis = 0)[::sbs]+
             (std(lighton_opti_test_90,axis = 0)[::sbs])/sqrt(shape(lighton_opti_test_90)[0]),
             mean(lighton_opti_test_90,axis = 0)[::sbs]-
             (std(lighton_opti_test_90,axis = 0)[::sbs])/sqrt(shape(lighton_opti_test_90)[0]),             
             alpha = 0.2,color = 'r',lw = 0)
plot(times[::sbs],mean(lighton_opti_test_90,axis = 0)[::sbs],'r')

fill_between(times[::sbs],
             mean(lighton_opti_test_270,axis = 0)[::sbs]+
             (std(lighton_opti_test_270,axis = 0)[::sbs])/sqrt(shape(lighton_opti_test_270)[0]),
             mean(lighton_opti_test_270,axis = 0)[::sbs]-
             (std(lighton_opti_test_270,axis = 0)[::sbs])/sqrt(shape(lighton_opti_test_270)[0]),             
             alpha = 0.2,color = 'b',lw = 0)
plot(times[::sbs],mean(lighton_opti_test_270,axis = 0)[::sbs],'b')

ax1.set_ybound(35,55)
ax2.set_ybound(35,55)
ax3.set_ybound(35,55)

ax4 = subplot(4,2,2)
ax5 = subplot(4,2,4,sharex = ax0)
ax6 = subplot(4,2,6,sharex = ax0)
ax7 = subplot(4,2,8,sharex = ax0)

axes(ax4)
plot(times[::sbs],stim[::sbs],'r')
plot(times[::sbs],stim[::sbs]*-1,'b')

axes(ax5)
fill_between(times[::sbs],
             mean(lightoff_static_test_90,axis = 0)[::sbs]+
             (std(lightoff_static_test_90,axis = 0)[::sbs])/sqrt(shape(lightoff_static_test_90)[0]),
             mean(lightoff_static_test_90,axis = 0)[::sbs]-
             (std(lightoff_static_test_90,axis = 0)[::sbs])/sqrt(shape(lightoff_static_test_90)[0]),             
             alpha = 0.2,color = 'r',lw = 0)
plot(times[::sbs],mean(lightoff_static_test_90,axis = 0)[::sbs],'r')

fill_between(times[::sbs],
             mean(lightoff_static_test_270,axis = 0)[::sbs]+
             (std(lightoff_static_test_270,axis = 0)[::sbs])/sqrt(shape(lightoff_static_test_270)[0]),
             mean(lightoff_static_test_270,axis = 0)[::sbs]-
             (std(lightoff_static_test_270,axis = 0)[::sbs])/sqrt(shape(lightoff_static_test_270)[0]),             
             alpha = 0.2,color = 'b',lw = 0)
plot(times[::sbs],mean(lightoff_static_test_270,axis = 0)[::sbs],'b')

axes(ax6)

fill_between(times[::sbs],
             mean(lightoff_stripe_test_90,axis = 0)[::sbs]+
             (std(lightoff_stripe_test_90,axis = 0)[::sbs])/sqrt(shape(lightoff_stripe_test_90)[0]),
             mean(lightoff_stripe_test_90,axis = 0)[::sbs]-
             (std(lightoff_stripe_test_90,axis = 0)[::sbs])/sqrt(shape(lightoff_stripe_test_90)[0]),             
             alpha = 0.2,color = 'r',lw = 0)
plot(times[::sbs],mean(lightoff_stripe_test_90,axis = 0)[::sbs],'r')

fill_between(times[::sbs],
             mean(lightoff_stripe_test_270,axis = 0)[::sbs]+
             (std(lightoff_stripe_test_270,axis = 0)[::sbs])/sqrt(shape(lightoff_stripe_test_270)[0]),
             mean(lightoff_stripe_test_270,axis = 0)[::sbs]-
             (std(lightoff_stripe_test_270,axis = 0)[::sbs])/sqrt(shape(lightoff_stripe_test_270)[0]),             
             alpha = 0.2,color = 'b',lw = 0)
plot(times[::sbs],mean(lightoff_stripe_test_270,axis = 0)[::sbs],'b')

axes(ax7)

fill_between(times[::sbs],
             mean(lightoff_opti_test_90,axis = 0)[::sbs]+
             (std(lightoff_opti_test_90,axis = 0)[::sbs])/sqrt(shape(lighton_opti_test_90)[0]),
             mean(lightoff_opti_test_90,axis = 0)[::sbs]-
             (std(lightoff_opti_test_90,axis = 0)[::sbs])/sqrt(shape(lighton_opti_test_90)[0]),             
             alpha = 0.2,color = 'r',lw = 0)
plot(times[::sbs],mean(lightoff_opti_test_90,axis = 0)[::sbs],'r')

fill_between(times[::sbs],
             mean(lightoff_opti_test_270,axis = 0)[::sbs]+
             (std(lightoff_opti_test_270,axis = 0)[::sbs])/sqrt(shape(lightoff_opti_test_270)[0]),
             mean(lightoff_opti_test_270,axis = 0)[::sbs]-
             (std(lightoff_opti_test_270,axis = 0)[::sbs])/sqrt(shape(lightoff_opti_test_270)[0]),             
             alpha = 0.2,color = 'b',lw = 0)
plot(times[::sbs],mean(lightoff_opti_test_270,axis = 0)[::sbs],'b')

ax5.set_ybound(35,55)
ax6.set_ybound(35,55)
ax7.set_ybound(35,55)
savefig('baseline_analysis.pdf')

# %%
import os
os.system("python test_analysis.py /media/FlyDataB/FlyDB/Fly0194/")
# Out:
# 0

# %%
os.system("python test_analysis.py /media/FlyDataB/FlyDB/Fly0195/")

# %%
os.system("python test_analysis.py /media/FlyDataB/FlyDB/Fly0196/")

# %%
import flylib as flb
import neo
import os
import gc

rootdir = '/media/FlyDataB/FlyDB/Fly0199/'
abf_file = filter(lambda x:'.abf' in x,os.listdir(rootdir))[0]
sigs = flb.get_axon_signals(rootdir + abf_file)
gc.collect()
idxs = flb.idx_by_thresh(sigs['DAC2'],thresh = 0)
t_codes = np.array([sigs['DAC2'][x] for x in idxs])
t_vals = around(array([mean(tc) for tc in t_codes])*6)
t_args = argsort(t_vals)
static_test_90 = squeeze(argwhere(t_vals == 10))
static_test_270 = squeeze(argwhere(t_vals == 20))
stripe_test_90 = squeeze(argwhere(t_vals == 30))
stripe_test_270 = squeeze(argwhere(t_vals == 40))
opti_test_90 = squeeze(argwhere(t_vals == 50))
opti_test_270 = squeeze(argwhere(t_vals == 60))
lmrs = np.array([sigs['Ph2'][x[:280000]] for x in idxs])
lwings = np.array([sigs['Ph0'][x[:280000]] for x in idxs])
rwings = np.array([sigs['Ph1'][x[:280000]] for x in idxs])
Ypos = np.array([sigs['Ypos'][x[:280000]] for x in idxs])
Xpos = np.array([sigs['Xpos'][x[:280000]] for x in idxs])
ttype = static_test_90
####################
figure()
subplot(3,1,1)
ave = mean(Ypos[ttype],axis=0)
stdev = std(Ypos[ttype],axis=0)
plot(ave,c = 'k')
plot(ave+stdev,c = 'b')
plot(ave-stdev,c = 'b')
i = 2
for ttype in [static_test_90,static_test_270]:
    subplot(3,1,i)
    ave = mean(lwings[ttype],axis=0)
    stdev = std(lwings[ttype],axis=0)
    plot(ave,c = 'k')
    plot(ave+stdev,c = 'b')
    plot(ave-stdev,c = 'b')
    i+=1
    gca().set_ybound(-3,3)
suptitle('static')

##################
figure()
subplot(3,1,1)
ave = mean(Ypos[ttype],axis=0)
stdev = std(Ypos[ttype],axis=0)
plot(ave,c = 'k')
plot(ave+stdev,c = 'b')
plot(ave-stdev,c = 'b')
i = 2
for ttype in [opti_test_90,opti_test_270]:
    subplot(3,1,i)
    ave = mean(lwings[ttype],axis=0)
    stdev = std(lwings[ttype],axis=0)
    plot(ave,c = 'k')
    plot(ave+stdev,c = 'b')
    plot(ave-stdev,c = 'b')
    i+=1
    gca().set_ybound(-3,3)
suptitle('opti')

##################
figure()
subplot(3,1,1)
ave = mean(Ypos[ttype],axis=0)
stdev = std(Ypos[ttype],axis=0)
plot(ave,c = 'k')
plot(ave+stdev,c = 'b')
plot(ave-stdev,c = 'b')
i = 2
for ttype in [stripe_test_90,stripe_test_270]:
    subplot(3,1,i)
    ave = mean(lwings[ttype],axis=0)
    stdev = std(lwings[ttype],axis=0)
    plot(ave,c = 'k')
    plot(ave+stdev,c = 'b')
    plot(ave-stdev,c = 'b')
    i+=1
    gca().set_ybound(-3,3)
suptitle('stripe')


ave_dict_lmr = {'static_test_90':mean(lmrs[static_test_90],axis=0),
            'static_test_270':mean(lmrs[static_test_270],axis=0),
            'stripe_test_90':mean(lmrs[stripe_test_90],axis=0),
            'stripe_test_270':mean(lmrs[stripe_test_270],axis=0),
            'opti_test_90':mean(lmrs[opti_test_90],axis=0),
            'opti_test_270':mean(lmrs[opti_test_270],axis=0)}

ave_dict_lwings = {'static_test_90':mean(lwings[static_test_90],axis=0),
            'static_test_270':mean(lwings[static_test_270],axis=0),
            'stripe_test_90':mean(lwings[stripe_test_90],axis=0),
            'stripe_test_270':mean(lwings[stripe_test_270],axis=0),
            'opti_test_90':mean(lwings[opti_test_90],axis=0),
            'opti_test_270':mean(lwings[opti_test_270],axis=0)}

ave_dict_rwings = {'static_test_90':mean(rwings[static_test_90],axis=0),
            'static_test_270':mean(rwings[static_test_270],axis=0),
            'stripe_test_90':mean(rwings[stripe_test_90],axis=0),
            'stripe_test_270':mean(rwings[stripe_test_270],axis=0),
            'opti_test_90':mean(rwings[opti_test_90],axis=0),
            'opti_test_270':mean(rwings[opti_test_270],axis=0)}



import cPickle
f = open(rootdir + 'T2_trial1_ave_data.cpkl','wb')
cPickle.dump({'lmr':ave_dict_lmr,'lwings':ave_dict_lwings,'rwings':ave_dict_rwings},f)
f.close()

# %%
stim_data = {'stim':mean(Ypos[ttype],axis=0)}
f = open(rootdir + 'stim_data.cpkl','wb')
cPickle.dump(stim_data,f)
f.close()

# %%
rootdir
# Out:
# '/media/FlyDataB/FlyDB/Fly0195/'

# %%
1.2/0.6
# Out:
# 2.0

# %%
abf_file
# Out:
# 'T2_trial2_14808005.abf'

# %%
fls = os.listdir(rootdir)

# %%
# Out:
# 'T2_trial1_14805002.abf'

# %%
400/156.0
# Out:
# 2.5641025641025643

# %%
# Out:
# array([ 20.,  20.,  20.,  20.,  20.,  20.,  20.,  20.,  20.,  20.,  20.,
#         20.], dtype=float32)

# %%
1.12/(274*2.5/1000)
# Out:
# 1.635036496350365

# %%
####################
figure()
subplot(3,1,1)
ave = mean(Ypos[ttype],axis=0)
stdev = std(Ypos[ttype],axis=0)
plot(ave,c = 'k')
plot(ave+stdev,c = 'b')
plot(ave-stdev,c = 'b')
i = 2
for ttype in [static_test_90,static_test_270]:
    subplot(3,1,i)
    ave = mean(rwings[ttype],axis=0)
    stdev = std(rwings[ttype],axis=0)
    plot(ave,c = 'k')
    plot(ave+stdev,c = 'b')
    plot(ave-stdev,c = 'b')
    i+=1
    gca().set_ybound(-3,3)
suptitle('static')

##################
figure()
subplot(3,1,1)
ave = mean(Ypos[ttype],axis=0)
stdev = std(Ypos[ttype],axis=0)
plot(ave,c = 'k')
plot(ave+stdev,c = 'b')
plot(ave-stdev,c = 'b')
i = 2
for ttype in [opti_test_90,opti_test_270]:
    subplot(3,1,i)
    ave = mean(rwings[ttype],axis=0)
    stdev = std(rwings[ttype],axis=0)
    plot(ave,c = 'k')
    plot(ave+stdev,c = 'b')
    plot(ave-stdev,c = 'b')
    i+=1
    gca().set_ybound(-3,3)
suptitle('opti')

##################
figure()
subplot(3,1,1)
ave = mean(Ypos[ttype],axis=0)
stdev = std(Ypos[ttype],axis=0)
plot(ave,c = 'k')
plot(ave+stdev,c = 'b')
plot(ave-stdev,c = 'b')
i = 2
for ttype in [stripe_test_90,stripe_test_270]:
    subplot(3,1,i)
    ave = mean(rwings[ttype],axis=0)
    stdev = std(rwings[ttype],axis=0)
    plot(ave,c = 'k')
    plot(ave+stdev,c = 'b')
    plot(ave-stdev,c = 'b')
    i+=1
    gca().set_ybound(-3,3)
suptitle('stripe')
